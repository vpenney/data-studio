# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

import pandas as pd
import re

# %%
# open Chrome
driver = webdriver.Chrome()

# %%
# go to FDIC site
url = "https://www.fdic.gov/bank/historical/bank/"
driver.get(url)

# %%
# find historical data for 2001
year1 = driver.find_element_by_name('2001')
year1.click()

# %%
# find each of the inconsistent rows in this horrid table
table_rows = driver.find_elements_by_tag_name("tbody")[2].find_elements_by_tag_name("tr")

# %%
for row in table_rows:
    cells = row.find_elements_by_tag_name("td")
    for cell in cells:
        print(cell.text)
# Out:
# September
# Sinclair National Bank, Gravette, AR
# PR-63-2001
# September 7, 2001
# $30.7
# $25.7
# Delta Trust and Bank, Parkdale, AR agreed to assume all insured deposits. (BIF)
# July
# Superior Bank, FSB, Hinsdale, IL
# PR-52-2001
# July 27, 2001
# $2,300.0
# $1,600.0
# The Federal Deposit Insurance Corporation today transferred the insured deposits and substantially all the assets of Superior Bank, FSB, Hinsdale, IL, to Superior Federal, FSB (New Superior), a newly chartered, full-service mutual savings bank. The bank was closed earlier today by the Office of Thrift Supervision, and the FDIC was named conservator. (SAIF)
# May
# The Malta National Bank, Malta,OH
# PR-32-2001
# May 3, 2001
# $9.5
# $8.8
# North Valley Bank, Zanesville, OH agreed to assume all deposits. (BIF)
# February
# First Alliance Bank & Trust Company, Manchester, NH
# PR-11-2001
# February 2, 2001
# $18.4
# $17.5
# Southern New Hampshire Bank and Trust Company, Salem, NH agreed to assume all deposits.

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2001 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2001['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2001['approx_assets'] = approx_assets
        info2001['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2001['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2001['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2001)
print(info2001)
# Out:
# {'bank_name': 'First Alliance Bank & Trust Company, Manchester, NH', 'approx_assets': '$18.4', 'approx_deposit': '$17.5', 'acquirer': 'Southern New Hampshire Bank and Trust Company, Salem, NH agreed to assume all deposits.', 'closing_date': 'February 2, 2001'}

# %%
df_2001 = pd.DataFrame(rows)

# %%
df_2001.dropna(inplace=True)
df_2001
# Out:
#                                             acquirer approx_assets  \
# 2  Delta Trust and Bank, Parkdale, AR agreed to a...         $30.7
# 4  The Federal Deposit Insurance Corporation toda...      $2,300.0
# 6  North Valley Bank, Zanesville, OH agreed to as...          $9.5
# 8  Southern New Hampshire Bank and Trust Company,...         $18.4
#
#   approx_deposit                                          bank_name  \
# 2          $25.7               Sinclair National Bank, Gravette, AR
# 4       $1,600.0                   Superior Bank, FSB, Hinsdale, IL
# 6           $8.8                  The Malta National Bank, Malta,OH
# 8          $17.5  First Alliance Bank & Trust Company, Mancheste...
#
#         closing_date
# 2  September 7, 2001
# 4      July 27, 2001
# 6        May 3, 2001
# 8   February 2, 2001

# %% [markdown]
# ## Here's data for 2002

# %%
# find historical data for 2002
year2 = driver.find_elements_by_class_name('yr-button')[1]
year2.click()

# %%
# find each of the inconsistent rows in this horrid table, which is now in a new place
table_rows = driver.find_elements_by_tag_name("tbody")[4].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2002 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2002['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2002['approx_assets'] = approx_assets
        info2002['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2002['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2002['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2002)
print(info2002)
# Out:
# {'bank_name': 'Hamilton Bank, National Association, Miami, FL', 'approx_assets': '$1,200.0', 'approx_deposit': '$1,300.0', 'acquirer': 'Israel Discount Bank of New York, New York, NY greed to assume all deposits. (BIF)', 'closing_date': 'January 11, 2002'}

# %%
df_2002 = pd.DataFrame(rows)

# %%
df_2002.dropna(inplace=True)
df_2002
# Out:
#                                              acquirer approx_assets  \
# 2   Sabine State Bank and Trust Company, Many, LA ...         $37.0
# 4   The FDIC has approved the payout of the insure...         $69.4
# 6   The FDIC has approved the payout of the insure...         $12.0
# 8   Chicago Community Bank, Chicago, IL agreed to ...         $52.0
# 9   Hudson United Bank, Mahwah, NJ agreed to assum...        $398.6
# 11  The FDIC has approved the payout of the insure...         $19.0
# 12  Bank Leumi USA of New York, NY agreed to assum...         $34.7
# 14  The FDIC has approved the payout of the insure...        $700.0
# 15  The State Bank and Trust Company of Defiance, ...         $72.3
# 17  The Security State Bank of Pecos, Pecos, TX gr...         $10.8
# 18  Israel Discount Bank of New York, New York, NY...      $1,200.0
#
#    approx_deposit                                          bank_name  \
# 2           $33.1  Farmers Bank & Trust of Cheneyville, Cheneyvil...
# 4           $55.3                           Bank of Alamo, Alamo, TN
# 6           $10.2            AmTrade International Bank, Atlanta, GA
# 8           $40.0        Universal Federal Savings Bank, Chicago, IL
# 9          $323.7         Connecticut Bank of Commerce, Stamford, CT
# 11          $18.0              New Century Bank, Shelby Township, MI
# 12          $23.9              Net 1st National Bank, Boca Raton, FL
# 14         $554.0        NextBank, National Association, Phoenix, AR
# 15          $60.2          Oakwood Deposit Bank Company, Oakwood, OH
# 17           $9.8        Bank of Sierra Blanca, Sierra Blanca, Texas
# 18       $1,300.0     Hamilton Bank, National Association, Miami, FL
#
#           closing_date
# 2    December 17, 2002
# 4     November 8, 2002
# 6   September 30, 2002
# 8        June 27, 2002
# 9        June 26, 2002
# 11      March 28, 2002
# 12       March 1, 2002
# 14    February 7, 2002
# 15    February 1, 2002
# 17    January 18, 2002
# 18    January 11, 2002

# %% [markdown]
# ## 2003, a.k.a. There's gotta be a better way to do this

# %%
# find historical data for 2003
year3 = driver.find_elements_by_class_name('yr-button')[2]
year3.click()

# %%
# find each of the inconsistent rows in this horrid table, which is now in a new place AGAIN
table_rows = driver.find_elements_by_tag_name("tbody")[6].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2003 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2003['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2003['approx_assets'] = approx_assets
        info2003['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2003['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2003['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2003)
print(info2003)
# Out:
# {'bank_name': 'Southern Pacific Bank, Torrance, CA', 'approx_assets': '$1,000.0', 'approx_deposit': '$865.0', 'acquirer': 'Beal Bank of Plano, TX agreed to assume all deposits. (BIF)', 'closing_date': 'February 7, 2003'}

# %%
df_2003 = pd.DataFrame(rows)

# %%
df_2003.dropna(inplace=True)
df_2003
# Out:
#                                             acquirer approx_assets  \
# 2  Earthstar Bank, South Hampton, PA agreed to as...         $10.2
# 4  The Park Bank, Madison, WI agreed to assume al...         $35.0
# 6  Beal Bank of Plano, TX agreed to assume all de...      $1,000.0
#
#   approx_deposit                                          bank_name  \
# 2           $9.2             Pulaski Savings Bank, Philadelphia, PA
# 4          $29.0  First National Bank of Blanchardville, Blancha...
# 6         $865.0                Southern Pacific Bank, Torrance, CA
#
#         closing_date
# 2  November 14, 2003
# 4        May 9, 2003
# 6   February 7, 2003

# %% [markdown]
# ## 2004

# %%
# find historical data for 2004
year4 = driver.find_elements_by_class_name('yr-button')[3]
year4.click()

# %%
# failing to comprehend this migrating table location
table_rows = driver.find_elements_by_tag_name("tbody")[8].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2004 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2004['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2004['approx_assets'] = approx_assets
        info2004['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2004['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2004['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2004)
print(info2004)
# Out:
# {'bank_name': 'Dollar Savings Bank of Newark, NJ', 'approx_assets': '$12.3', 'approx_deposit': '$9.8', 'acquirer': 'The FDIC has approved the payout of the insured deposits of Dollar Savings Bank of Newark. (SAIF)', 'closing_date': 'February 14, 2004'}

# %%
df_2004 = pd.DataFrame(rows)

# %%
df_2004.dropna(inplace=True)
df_2004
# Out:
#                                             acquirer approx_assets  \
# 2  Far West Bank, Provo, UT agreed to assume all ...         $46.4
# 4  Union State Bank, Orangeburg, NY agreed to ass...         $30.3
# 5  Hancock Bank of Florida, Tallahassee, FL agree...         $74.1
# 7  The FDIC has approved the payout of the insure...         $12.3
#
#   approx_deposit                                          bank_name  \
# 2          $45.2                       Bank of Ephraim, Ephraim, UT
# 4          $28.0                    Reliance Bank, White Plains, NY
# 5          $66.9  Guaranty National Bank of Tallahassee, Tallaha...
# 7           $9.8                  Dollar Savings Bank of Newark, NJ
#
#         closing_date
# 2      June 25, 2004
# 4     March 19, 2004
# 5     March 12, 2004
# 7  February 14, 2004

# %% [markdown]
# ## 2007, because there were no bank failures in '05 or '06. Maybe it was an omen. Maybe it wasn't.

# %%
# find historical data for 2007
year7 = driver.find_elements_by_class_name('yr-button')[6]
year7.click()

# %%
# migrating table info
table_rows = driver.find_elements_by_tag_name("tbody")[10].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2007 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2007['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2007['approx_assets'] = approx_assets
        info2007['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2007['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2007['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2007)
print(info2007)
# Out:
# {'bank_name': 'Metropolitan Savings, Pittsburgh, PA', 'approx_assets': '$15.8', 'approx_deposit': '$12.0', 'acquirer': 'Allegheny Valley Bank of Pittsburgh, PA has agreed to assume approximately $12.0 million of insured deposits.', 'closing_date': 'February 2, 2007'}

# %%
df_2007 = pd.DataFrame(rows)

# %%
df_2007.dropna(inplace=True)
df_2007
# Out:
#                                             acquirer approx_assets  \
# 2  The Citizens Banking Company, Sandusky, OH agr...         $86.7
# 4  ING Bank, fsb (ING DIRECT) has agreed to assum...      $2,500.0
# 6  Allegheny Valley Bank of Pittsburgh, PA has ag...         $15.8
#
#   approx_deposit                             bank_name        closing_date
# 2          $76.0       Miami Valley Bank, Lakeview, OH     October 4, 2007
# 4       $2,300.0               NetBank, Alpharetta, GA  September 28, 2007
# 6          $12.0  Metropolitan Savings, Pittsburgh, PA    February 2, 2007

# %% [markdown]
# ## 2008--are you having fun yet? I am.

# %%
# find historical data for 2008
year8 = driver.find_elements_by_class_name('yr-button')[7]
year8.click()

# %%
# migrating table info
table_rows = driver.find_elements_by_tag_name("tbody")[12].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2008 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2008['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2008['approx_assets'] = approx_assets
        info2008['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2008['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2008['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2008)
print(info2008)
# Out:
# {'bank_name': 'Douglass National Bank, Kansas City, MO', 'approx_assets': '$58.5', 'approx_deposit': '$53.8', 'acquirer': 'Liberty Bank and Trust Company of New Orleans, LA agreed to assume all deposits (approximately $53.8 million).', 'closing_date': 'January 25, 2008'}

# %%
df_2008 = pd.DataFrame(rows)

# %%
df_2008.dropna(inplace=True)
df_2008
# Out:
#                                              acquirer approx_assets  \
# 2   Pecos County State Bank, Fort Stockton, TX ass...         $37.0
# 3   Branch Banking and Trust Company, Winston-Sale...        $572.0
# 4      United Bank, Zebulon, GA assumed all deposits.        $237.5
# 6   In a transaction facilitated by the FDIC, U.S....      $3,700.0
# 7   In a transaction facilitated by the FDIC, U.S....     $12,800.0
# 8   Bank of Essex, Tappahannock, VA agreed to assu...        $681.0
# 9   Pacific Western Bank, Los Angeles, California ...        $561.1
# 10  Prosperity Bank, El Campo, TX agreed to assume...      $5,100.0
# 12  Fifth Third Bank of Grand Rapids, MI agreed to...        $287.0
# 13  Stearns Bank National Association, St. Cloud, ...        $354.1
# 14  National Bank of Hillsboro, IL assumed all dep...        $39.18
# 15  Monroe Bank & Trust of Monroe, MI agreeed to a...         $98.0
# 17  In a transaction facilitated by the FDIC, JPMo...    $307,000.0
# 18  Pioneer Community Bank, Inc., Iaeger, West Vir...        $115.0
# 19  Nevada State Bank, Las Vegas, NV agreed to ass...      $2,000.0
# 21  Regions Bank, Birmingham, AL agreed to assume ...      $1,100.0
# 22  Citizens Bank and Trust Company, Chillicothe, ...        $752.0
# 23  SunTrust Bank, Atlanta, GA agreed to assume th...        $259.0
# 25  Mutual of Omaha Bank, Omaha, Nebraska agreed t...      $3,400.0
# 26  Mutual of Omaha Bank, Omaha, NE agreed to assu...        $254.0
# 27  Non-brokered insured deposits and substantiall...     $32,010.0
# 29  First International Bank and Trust, Watford Ci...         $54.7
# 30  Pulaski Bank and Trust Company, Little Rock, A...      $2,100.0
# 32  Security Bank, Rich Hill, MO agreed to assume ...         $18.7
# 34  Liberty Bank and Trust Company of New Orleans,...         $58.5
#
#    approx_deposit                                          bank_name  \
# 2           $27.9                Sanderson State Bank, Sanderson, TX
# 3          $515.0                       Haven Trust Bank, Duluth, GA
# 4          $197.4          First Georgia Community Bank, Jackson, GA
# 6        $2,400.0                     PFF Bank and Trust, Pomona, CA
# 7        $9,700.0  Downey Savings and Loan Association, F.A., New...
# 8          $611.4                     Community Bank, Loganville, GA
# 9          $450.1             Security Pacific Bank, Los Angeles, CA
# 10       $3,700.0                    Franklin Bank, SSB, Houston, TX
# 12         $254.0                        Freedom Bank, Bradenton, FL
# 13         $346.2                 Alpha Bank & Trust, Alpharetta, GA
# 14         $36.88                          Meridian Bank, Eldred, IL
# 15          $86.0                   Main Street Bank, Northville, MI
# 17     $188,000.0                Washington Mutual Bank, Seattle, WA
# 18         $102.0                     Ameribank, Inc., Northfork, WV
# 19       $1,700.0                   Silver State Bank, Henderson, NV
# 21         $974.0                     Integrity Bank, Alpharetta, GA
# 22         $622.0               Columbian Bank and Trust, Topeka, KS
# 23         $227.0                 First Priority Bank, Bradenton, FL
# 25       $3,000.0            First National Bank of Nevada, Reno, NV
# 26         $233.0  First Heritage Bank National Association, Newp...
# 27       19,060.0                 IndyMac Bank, F.S.B., Pasadena, CA
# 29          $50.3  First Integrity Bank, National Association, St...
# 30       $1,800.0  ANB Financial, National Association, Bentonvil...
# 32          $13.6                                Hume Bank, Hume, MO
# 34          $53.8            Douglass National Bank, Kansas City, MO
#
#           closing_date
# 2    December 12, 2008
# 3    December 12, 2008
# 4     December 5, 2008
# 6    November 21, 2008
# 7    November 21, 2008
# 8    November 21, 2008
# 9     November 7, 2008
# 10    November 7, 2008
# 12    October 31, 2008
# 13    October 24, 2008
# 14    October 10, 2008
# 15    October 10, 2008
# 17  September 25, 2008
# 18  September 19, 2008
# 19   September 5, 2008
# 21     August 29, 2008
# 22     August 22, 2008
# 23      August 1, 2008
# 25       July 25, 2008
# 26       July 25, 2008
# 27       July 11, 2008
# 29        May 30, 2008
# 30         May 9, 2008
# 32       March 7, 2008
# 34    January 25, 2008

# %% [markdown]
# ## 2009

# %%
# find historical data for 2009
year9 = driver.find_elements_by_class_name('yr-button')[8]
year9.click()

# %%
# seriously, what's up with this table
table_rows = driver.find_elements_by_tag_name("tbody")[14].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2009 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2009['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2009['approx_assets'] = approx_assets
        info2009['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2009['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2009['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2009)
print(info2009)
# Out:
# {'bank_name': 'National Bank of Commerce, Berkeley, IL', 'approx_assets': '$430.9', 'approx_deposit': '$402.1', 'acquirer': "In addition to assuming all of the failed bank's deposits, Republic Bank of Chicago, Oak Brook, IL agreed to pay a discount of $44.9 million, and will purchase approximately $366.6 million of assets. The FDIC will retain the remaining assets for later disposition.", 'closing_date': 'January 16, 2009'}

# %%
df_2009 = pd.DataFrame(rows)

# %%
df_2009.dropna(inplace=True)
df_2009
# Out:
#                                               acquirer approx_assets  \
# 2    OneWest Bank, FSB, Pasadena, CA has agreed to ...      $6,100.0
# 3    City National Bank, Los Angeles, CA has agreed...      $4,000.0
# 4    The FDIC created a bridge bank, Independent Ba...        $585.5
# 5    Beal Bank, Plano, TX has agreed to assume all ...      $1,500.0
# 6    Deposit Insurance National Bank of New Baltimo...        $168.6
# 7    Hancock Bank, Gulfport, MS has agreed to assum...      $1,800.0
# 8    The FDIC has approved the payout of the insure...        $294.0
# 9    Arvest Bank, Fayetteville, AR has agreed to as...        $511.1
# 10   Enterprise Bank & Trust, Clayton, MO has agree...         $40.3
# 11   1st United Bank, Boca Raton, FL has agreed to ...        $433.0
# 12   Sonabank, McLean, VA has agreed to assume all ...        $203.0
# 13   MB Financial Bank, National Association, Chica...        $170.0
# 14   New York Community Bank, Westbury, NY has agre...     $12,000.0
# 15   HeritageBank of the South, Albany, GA has agre...         $49.6
# 16   State Bank and Trust Company, Macon, GA has ag...        $128.0
# 17   State Bank and Trust Company, Macon, GA has ag...        $874.0
# 19   Central Bank, Stillwater, MN has agreed to ass...         $79.7
# 20   Sunwest Bank, Tustin, CA has agreed to assume ...        $134.4
# 21   IBERIABANK, Lafayette, LA has agreed to assume...      $2,700.0
# 22   IBERIABANK, Lafayette, LA has agreed to assume...        $728.0
# 23   East West Bank, Pasadena, CA has agreed to ass...     $11,200.0
# 24   Central Bank of Kansas City, Kansas City, MO h...         $27.7
# 25   Alerus Financial, National Association, Grand ...        $199.5
# 26   Liberty Bank and Trust Company, New Orleans, L...         $14.9
# 27   Ameris Bank, Moultrie, GA has agreed to assume...        $157.0
# 29   U.S. Bank National Association, Minneapolis, M...        $326.2
# 30   U.S. Bank National Association, Minneapolis, M...        $256.7
# 31   U.S. Bank National Association, Minneapolis, M...        $118.2
# 32   U.S. Bank National Association, Minneapolis, M...      $4,700.0
# 33   U.S. Bank National Association, Minneapolis, M...      $2,300.0
# ..                                                 ...           ...
# 119  The FDIC created a bridge bank, Silverton Brid...      $4,100.0
# 121  U.S. Bank, National Association, Minneapolis, ...        $488.9
# 122  The FDIC has approved the payout of the insure...      $1,500.0
# 123  Level One Bank, Farmington Hills, MI, has agre...        $184.6
# 124  Bank of North Georgia, Alpharetta, GA, has agr...        $112.3
# 125  Nevada State Bank, Las Vegas, NV, has agreed t...        $270.9
# 126  Metcalf Bank, Lee's Summit, Missouri, has agre...        $181.0
# 127  Deposit Insurance National Bank of Greeley, Gr...      $2,000.0
# 128  First Federal Savings and Loan Association, Ch...        $492.0
# 130  SunTrust Bank, Atlanta, GA has agreed to assum...        $956.0
# 131  Great Southern Bank, Springfield, Missouri, ha...        $669.8
# 132  Herring Bank, Amarillo, TX has agreed to assum...        $123.5
# 133  The FDIC has approved the payout of the insure...        $297.0
# 134  Northeast Georgia Bank, Lavonia, Georgia has a...        $173.0
# 136  Bank of Nevada, Las Vegas, NV has agreed to as...        $238.3
# 137  The MB Financial Bank, National Association, C...        $232.9
# 138  Citizens Bank, Corvallis, Oregon has agreed to...        $131.4
# 139  Washington Trust Bank, Spokane, WA has agreed ...         $73.0
# 140  The Carlinville National Bank, Carlinville, Il...        $271.8
# 141  TIB Bank, Naples, Florida has agreed to assume...        $539.0
# 142  Heritage Bank, Wood River, NE has agreed to as...        $129.8
# 143  Westamerica Bank, San Rafael, CA has agreed to...      $1,700.0
# 144  California Bank & Trust, San Diego, California...      $1,140.0
# 145  Regions Bank, Birmingham, Alabama has agreed t...        $337.0
# 147  CenterState Bank of Florida, Winter Haven, FL ...        $223.5
# 148  Bank of Essex, Tappahannock, VA has agreed to ...        $360.0
# 149  The FDIC has approved the payout of the insure...        $292.9
# 150  First California Bank, Westlake Village, CA ha...        $803.3
# 151  Umpqua Bank, Roseburg, Oregon has agreed to as...        $446.5
# 152  In addition to assuming all of the failed bank...        $430.9
#
#     approx_deposit                                          bank_name  \
# 2         $4,500.0  First Federal Bank of California, F.S.B., Sant...
# 3         $2,800.0                Imperial Capital Bank, La Jolla, CA
# 4           $511.5         Independent Bankers' Bank, Springfield, IL
# 5         $1,200.0       New South Federal Savings Bank, Irondale, AL
# 6           $157.1             Citizens State Bank, New Baltimore, MI
# 7         $1,700.0      Peoples First Community Bank, Panama City, FL
# 8           $291.7            RockBridge Commercial Bank, Atlanta, GA
# 9           $421.3                   SolutionsBank, Overland Park, KS
# 10           $41.3  Valley Capital Bank, National Association, Mes...
# 11          $352.7  Republic Federal Bank, National Association, M...
# 12          $179.0                  Greater Atlantic Bank, Reston, VA
# 13          $181.0                         Benchmark Bank, Aurora, IL
# 14        $8,000.0                        AmTrust Bank, Cleveland, OH
# 15           $47.3                  The Tattnall Bank, Reidsville, GA
# 16          $123.0         First Security National Bank, Norcross, GA
# 17          $838.0           The Buckhead Community Bank, Atlanta, GA
# 19           $76.7  Commerce Bank of Southwest Florida, Fort Myers...
# 20          $130.9      Pacific Coast National Bank, San Clemente, CA
# 21        $2,100.0                             Orion Bank, Naples, FL
# 22          $631.0  Century Bank, a Federal Savings Bank, Sarasota...
# 23        $7,500.0          United Commercial Bank, San Francisco, CA
# 24           $27.9           Gateway Bank of St. Louis, St. Louis, MO
# 25          $175.6                        Prosperan Bank, Oakdale, MN
# 26           $12.8             Home Federal Savings Bank, Detroit, MI
# 27          $150.0                   United Security Bank, Sparta, GA
# 29          $308.0                    North Houston Bank, Houston, TX
# 30          $225.2          Madisonville State Bank, Madisonville, TX
# 31           $97.7                 Citizens National Bank, Teague, TX
# 32        $3,700.0                    Park National Bank, Chicago, IL
# 33        $1,800.0           Pacific National Bank, San Francisco, CA
# ..             ...                                                ...
# 119       $3,300.0  Silverton Bank, National Association, Atlanta, GA
# 121         $374.0                   First Bank of Idaho, Ketchum, ID
# 122       $1,000.0         First Bank of Beverly Hills, Calabasas, CA
# 123         $151.7       Michigan Heritage Bank, Farmington Hills, MI
# 124         $104.3               American Southern Bank, Kennesaw, GA
# 125         $221.4               Great Basin Bank of Nevada, Elko, NV
# 126         $171.9            American Sterling Bank, Sugar Creek, MO
# 127       $1,500.0                     New Frontier Bank, Greeley, CO
# 128         $403.0                     Cape Fear Bank, Wilmington, NC
# 130         $796.8                    Omni National Bank, Atlanta, GA
# 131         $492.8          TeamBank, National Association, Paola, KS
# 132          $82.7       Colorado National Bank, Colorado Springs, CO
# 133         $278.0                    FirstCity Bank, Stockbridge, GA
# 134         $161.0              Freedom Bank of Georgia, Commerce, GA
# 136         $175.2               Security Savings Bank, Henderson, NV
# 137         $218.6              Heritage Community Bank, Glenwood, IL
# 138         $116.3                   Silver Falls Bank, Silverton, OR
# 139          $64.0                       Pinnacle Bank, Beaverton, OR
# 140         $234.4   Corn Belt Bank and Trust Company, Pittsfield, IL
# 141         $424.0   Riverside Bank of the Gulf Coast, Cape Coral, FL
# 142          $85.1                 Sherman County Bank, Loup City, NE
# 143       $1,300.0                            County Bank, Merced, CA
# 144         $951.0                     Alliance Bank, Culver City, CA
# 145         $279.0        FirstBank Financial Services, McDonough, GA
# 147         $205.2                     Ocala National Bank, Ocala, FL
# 148         $302.0         Suburban Federal Savings Bank, Crofton, MD
# 149         $282.8                     MagnetBank, Salt Lake City, UT
# 150         $676.9                  1st Centennial Bank, Redlands, CA
# 151         $366.5                Bank of Clark County, Vancouver, WA
# 152         $402.1            National Bank of Commerce, Berkeley, IL
#
#           closing_date
# 2    December 18, 2009
# 3    December 18, 2009
# 4    December 18, 2009
# 5    December 18, 2009
# 6    December 18, 2009
# 7    December 18, 2009
# 8    December 18, 2009
# 9    December 11, 2009
# 10   December 11, 2009
# 11   December 11, 2009
# 12    December 4, 2009
# 13    December 4, 2009
# 14    December 4, 2009
# 15    December 4, 2009
# 16    December 4, 2009
# 17    December 4, 2009
# 19   November 20, 2009
# 20   November 13, 2009
# 21   November 13, 2009
# 22   November 13, 2009
# 23    November 6, 2009
# 24    November 6, 2009
# 25    November 6, 2009
# 26    November 6, 2009
# 27    November 6, 2009
# 29    October 30, 2009
# 30    October 30, 2009
# 31    October 30, 2009
# 32    October 30, 2009
# 33    October 30, 2009
# ..                 ...
# 119        May 1, 2009
# 121     April 24, 2009
# 122     April 24, 2009
# 123     April 24, 2009
# 124     April 24, 2009
# 125     April 17, 2009
# 126     April 17, 2009
# 127     April 10, 2009
# 128     April 10, 2009
# 130     March 27, 2009
# 131     March 20, 2009
# 132     March 20, 2009
# 133     March 20, 2009
# 134      March 6, 2009
# 136  February 27, 2009
# 137  February 27, 2009
# 138  February 20, 2009
# 139  February 13, 2009
# 140  February 13, 2009
# 141  February 13, 2009
# 142  February 13, 2009
# 143   February 6, 2009
# 144   February 6, 2009
# 145   February 6, 2009
# 147   January 30, 2009
# 148   January 30, 2009
# 149   January 30, 2009
# 150   January 23, 2009
# 151   January 16, 2009
# 152   January 16, 2009
#
# [140 rows x 5 columns]

# %% [markdown]
# ## 2010

# %%
# find historical data for 2010
year10 = driver.find_elements_by_class_name('yr-button')[9]
year10.click()

# %%
# find the table
table_rows = driver.find_elements_by_tag_name("tbody")[16].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2010 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2010['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2010['approx_assets'] = approx_assets
        info2010['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2010['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2010['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2010)
print(info2010)
# Out:
# {'bank_name': 'Horizon Bank, Bellingham, WA', 'approx_assets': '$1,300.0', 'approx_deposit': '$1,100.0', 'acquirer': 'Washington Federal Savings and Loan Association, Seattle, WA has agreed to assume all deposits, excluding certain brokered deposits.', 'closing_date': 'January 8, 2010'}

# %%
df_2010 = pd.DataFrame(rows)

# %%
df_2010.dropna(inplace=True)
df_2010
# Out:
#                                               acquirer approx_assets  \
# 2    Farmers & Merchants Savings Bank, Manchester, ...         $31.6
# 3    Southern Bank, Poplar Bluff, MO has agreed to ...        $191.8
# 4    State Bank and Trust Company, Macon, GA has ag...        $242.3
# 5    Peoples Bank of East Tennessee, Madisonville, ...         $68.2
# 6    Bank of the Ozarks, Little Rock, AR has agreed...        $244.4
# 7    1st United Bank, Boca Raton, FL has agreed to ...        $448.2
# 8    Polonia Bank, Huntingdon Valley, PA has agreed...        $112.6
# 9    Level One Bank, Farmington Hills, MI has agree...        $252.7
# 11   First Michigan Bank, Troy, MI has agreed to as...        $750.7
# 12   VIST Bank, Wyomissing, PA has agreed to assume...        $106.6
# 13   Centennial Bank, Conway, AR has agreed to assu...        $112.1
# 14   Stearns Bank National Association, Saint Cloud...        $204.0
# 15   Ameris Bank, Moultrie, GA has agreed to assume...        $654.7
# 16   Ameris Bank, Moultrie, GA has agreed to assume...        $143.7
# 17   Grandpoint Bank, Los Angeles, CA has agreed to...         $48.0
# 18   Heritage Bank, Olympia, WA has agreed to assum...        $221.1
# 19   First California Bank, Westlake Village, CA ha...         $98.6
# 20   Manufacturers and Traders Trust Company, Buffa...        $538.3
# 22   The FDIC has approved the payout of the insure...        $272.2
# 23   Hillcrest Bank, National Association, Overland...      $1,650.0
# 24   Seaway Bank and Trust Company, Chicago, IL has...        $148.7
# 25   United Bank, Zebulon, GA has agreed to assume ...        $131.4
# 26   Morris Bank, Dublin, GA has agreed to assume a...         $29.4
# 27   Bay Cities Bank, Tampa, FL has agreed to assum...        $110.7
# 28   Ameris Bank, Moultrie, GA has agreed to assume...         $81.0
# 29   Providence Bank, Columbia, MO has agreed to as...      $1,180.0
# 30   Midland States Bank, Effingham, IL has agreed ...         $91.5
# 31   Simmons First National Bank, Pine Bluff, AR ha...        $508.4
# 32   GBC International Bank, Los Angeles, CA has ag...        $104.2
# 33   Centennial Bank, Conway, AR has agreed to assu...        $424.1
# ..                                                 ...           ...
# 138  Home Bank, Lafayette, LA has agreed to assume ...        $243.2
# 139  Centennial Bank, Conway, AR has agreed to assu...        $315.6
# 140  Valley National Bank, Wayne, NJ has agreed to ...        $520.1
# 141  Valley National Bank, Wayne, NJ has agreed to ...        $209.7
# 142  The FDIC has approved the payout of the insure...        $215.2
# 143  To protect the insured depositors, the FDIC cr...        $155.6
# 144  Heartland Bank and Trust Company, Bloomington,...        $211.7
# 145  First-Citizens Bank & Trust Company, Raleigh, ...        $535.7
# 147  Umpqua Bank, Roseburg, OR has agreed to assume...        $717.8
# 148  Heritage Bank of Nevada, Reno, NV has agreed t...         $51.1
# 149  OneWest Bank, FSB, Pasadena, CA has agreed to ...      $3,600.0
# 150  FirstMerit Bank, National Association, Akron, ...        $412.8
# 151  Community National Bank, Hondo, TX has agreed ...         $53.9
# 152  Mutual of Omaha Bank, Omaha, NE has agreed to ...        $119.6
# 153  Community Development Bank, FSB, Ogema, MN has...         $18.2
# 155  Columbia State Bank, Tacoma, WA has agreed to ...        $373.2
# 156  First-Citizens Bank & Trust Company, Raleigh, ...      $2,180.0
# 157  SCBT National Association, Orangeburg, SC has ...      $1,210.0
# 158  United Valley Bank, Cavalier, ND has agreed to...         $59.9
# 159  Premier American Bank, National Association, M...        $875.5
# 160  Community and Southern Bank, Carrollton, GA ha...        $832.6
# 161  Columbia State Bank, Tacoma, WA has agreed to ...      $1,100.0
# 162  Umpqua Bank, Roseburg, OR has agreed to assume...        $488.5
# 163  Charter Bank, Albuquerque, NM has agreed to as...      $1,200.0
# 164  Sunflower Bank, National Association, Salina, ...         $20.1
# 165  Premier American Bank, National Association, M...        $350.9
# 166  The FDIC has created the Deposit Insurance Nat...        $827.8
# 167  First State Bank of St. Joseph, St. Joseph, MN...         $24.7
# 168  First American Bank, Elk Grove Village, IL has...         $69.6
# 169  Washington Federal Savings and Loan Associatio...      $1,300.0
#
#     approx_deposit                                          bank_name  \
# 2            $28.8            Community National Bank, Lino Lakes, MN
# 3           $155.8                First Southern Bank, Batesville, AR
# 4           $193.8  United Americas Bank, National Association, At...
# 5            $76.4   Appalachian Community Bank, FSB, McCaysville, GA
# 6           $240.5              Chestatee State Bank, Dawsonville, GA
# 7           $374.2  The Bank of Miami, National Association, Coral...
# 8           $104.5                    Earthstar Bank, Southampton, PA
# 9           $213.6               Paramount Bank, Farmington Hills, MI
# 11          $664.8               First Banking Center, Burlington, WI
# 12           $92.0  Allegiance Bank of North America, Bala Cynwyd, PA
# 13          $112.2          Gulf State Community Bank, Carrabelle, FL
# 14          $190.2                   Copper Star Bank, Scottsdale, AZ
# 15          $587.6                Darby Bank & Trust Co., Vidalia, GA
# 16          $141.6                 Tifton Banking Company, Tifton, GA
# 17           $47.0    First Vietnamese American Bank, Westminster, CA
# 18          $193.5                 Pierce Commercial Bank, Tacoma, WA
# 19          $101.1        Western Commercial Bank, Woodland Hills, CA
# 20          $500.1                           K Bank, Randallstown, MD
# 22          $198.8       First Arizona Savings, A FSB, Scottsdale, AZ
# 23        $1,540.0                  Hillcrest Bank, Overland Park, KS
# 24          $140.0          First Suburban National Bank, Maywood, IL
# 25          $127.1  The First National Bank of Barnesville, Barnes...
# 26           $26.7                        The Gordon Bank, Gordon, GA
# 27          $101.3                Progress Bank of Florida, Tampa, FL
# 28           $77.3       First Bank of Jacksonville, Jacksonville, FL
# 29        $1,030.0                   Premier Bank, Jefferson City, MO
# 30           $72.5  WestBridge Bank and Trust Company, Chesterfiel...
# 31          $397.0          Security Savings Bank, F.S.B., Olathe, KS
# 32          $100.2                      Shoreline Bank, Shoreline, WA
# 33          $386.3                    Wakulla Bank, Crawfordville, FL
# ..             ...                                                ...
# 138         $208.8                      Statewide Bank, Covington, LA
# 139         $319.7                     Old Southern Bank, Orlando, FL
# 140         $494.5                     Park Avenue Bank, New York, NY
# 141         $209.5                   LibertyPointe Bank, New York, NY
# 142         $205.1                         Centennial Bank, Ogden, UT
# 143         $156.4                    Waterfield Bank, Germantown, MD
# 144         $198.5                       Bank of Illinois, Normal, IL
# 145         $443.5                  Sun American Bank, Boca Raton, FL
# 147         $446.2                   Rainier Pacific Bank, Tacoma, WA
# 148          $50.0       Carson River Community Bank, Carson City, NV
# 149       $2,800.0                   La Jolla Bank, FSB, La Jolla, CA
# 150         $395.3    George Washington Savings Bank, Orland Park, IL
# 151          $49.3           The La Coste National Bank, La Coste, TX
# 152         $117.1             Marco Community Bank, Marco Island, FL
# 153          $16.3  1st American State Bank of Minnesota, Hancock, MN
# 155         $308.5        American Marine Bank, Bainbridge Island, WA
# 156       $1,870.0               First Regional Bank, Los Angeles, CA
# 157       $1,110.0             Community Bank and Trust, Cornelia, GA
# 158          $54.7   Marshall Bank, National Association, Hallock, MN
# 159         $795.5              Florida Community Bank, Immokalee, FL
# 160         $757.9     First National Bank of Georgia, Carrollton, GA
# 161       $1,000.0                Columbia River Bank, The Dalles, OR
# 162         $439.4                        Evergreen Bank, Seattle, WA
# 163         $851.5                         Charter Bank, Santa Fe, NM
# 164          $20.4                         Bank of Leeton, Leeton, MO
# 165         $326.3                   Premier American Bank, Miami, FL
# 166         $786.5              Barnes Banking Company, Kaysville, UT
# 167          $23.4            St. Stephen State Bank, St. Stephen, MN
# 168          $67.4         Town Community Bank and Trust, Antioch, IL
# 169       $1,100.0                       Horizon Bank, Bellingham, WA
#
#           closing_date
# 2    December 17, 2010
# 3    December 17, 2010
# 4    December 17, 2010
# 5    December 17, 2010
# 6    December 17, 2010
# 7    December 17, 2010
# 8    December 10, 2010
# 9    December 10, 2010
# 11   November 19, 2010
# 12   November 19, 2010
# 13   November 19, 2010
# 14   November 12, 2010
# 15   November 12, 2010
# 16   November 12, 2010
# 17    November 5, 2010
# 18    November 5, 2010
# 19    November 5, 2010
# 20    November 5, 2010
# 22    October 22, 2010
# 23    October 22, 2010
# 24    October 22, 2010
# 25    October 22, 2010
# 26    October 22, 2010
# 27    October 22, 2010
# 28    October 22, 2010
# 29    October 15, 2010
# 30    October 15, 2010
# 31    October 15, 2010
# 32     October 1, 2010
# 33     October 1, 2010
# ..                 ...
# 138     March 12, 2010
# 139     March 12, 2010
# 140     March 12, 2010
# 141     March 11, 2010
# 142      March 5, 2010
# 143      March 5, 2010
# 144      March 5, 2010
# 145      March 5, 2010
# 147  February 26, 2010
# 148  February 26, 2010
# 149  February 19, 2010
# 150  February 19, 2010
# 151  February 19, 2010
# 152  February 19, 2010
# 153   February 5, 2010
# 155   January 29, 2010
# 156   January 29, 2010
# 157   January 29, 2010
# 158   January 29, 2010
# 159   January 29, 2010
# 160   January 29, 2010
# 161   January 22, 2010
# 162   January 22, 2010
# 163   January 22, 2010
# 164   January 22, 2010
# 165   January 22, 2010
# 166   January 15, 2010
# 167   January 15, 2010
# 168   January 15, 2010
# 169    January 8, 2010
#
# [157 rows x 5 columns]

# %% [markdown]
# ## 2011

# %%
# find historical data for 2011
year11 = driver.find_elements_by_class_name('yr-button')[10]
year11.click()

# %%
# favorite table
table_rows = driver.find_elements_by_tag_name("tbody")[18].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2011 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2011['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2011['approx_assets'] = approx_assets
        info2011['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2011['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2011['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2011)
print(info2011)
# Out:
# {'bank_name': 'First Commercial Bank of Florida, Orlando, FL', 'approx_assets': '$598.5', 'approx_deposit': '$529.6', 'acquirer': 'First Southern Bank, Boca Raton, FL has agreed to assume all deposits excluding certain brokered deposits.', 'closing_date': 'January 7, 2011'}

# %%
df_2011 = pd.DataFrame(rows)

# %%
df_2011.dropna(inplace=True)
df_2011
# Out:
#                                               acquirer approx_assets  \
# 2    Washington Federal, Seattle, WA has agreed to ...        $162.9
# 3    Summit Bank, National Association, Panama City...        $126.0
# 5    First NBC Bank, New Orleans, LA has agreed to ...        $383.1
# 6    Grinnell State Bank, Grinnell, IA has agreed t...         $91.6
# 7    Century Bank of Georgia, Cartersville, GA has ...         $62.4
# 8    Cache Valley Bank, Logan, UT has agreed to ass...        $198.1
# 9    Premier Bank (formerly Purdum State Bank), Pur...        $106.1
# 11   International Bank of Chicago, Chicago, IL has...         $37.8
# 12   Bank Midwest, National Association, Kansas Cit...      $1,380.0
# 13   State Bank and Trust Company, Macon, GA has ag...        $181.2
# 14   Fidelity Bank, Atlanta, GA has agreed to assum...        $191.5
# 15   1st United Bank, Boca Raton, FL has agreed to ...        $215.9
# 16   Blackhawk Bank & Trust, Milan, IL has agreed t...        $190.6
# 17   Northfield Bank, Staten Island, NY has agreed ...        $204.4
# 18   Bank of North Carolina, Thomasville, NC has ag...        $161.0
# 19   State Bank and Trust Company, Macon, GA has ag...        $201.7
# 20   Great Southern Bank, Springfield, MO has agree...        $355.9
# 21   Central Bank, Stillwater, MN has agreed to ass...        $417.4
# 23   American First National Bank, Houston, TX has ...        $239.9
# 24   Tri Counties Bank, Chico, CA has agreed to ass...        $288.8
# 25   Southern Bank and Trust Company, Mount Olive, ...        $985.1
# 26   CharterBank, West Point, GA has agreed to assu...        $296.8
# 27   Georgia Commerce Bank, Atlanta, GA has agreed ...        $102.3
# 28   Georgia Commerce Bank, Atlanta, GA has agreed ...        $150.8
# 30   Inland Bank & Trust, Oak Brook, IL has agreed ...        $141.0
# 31   Heritage Bank of the South, Albany, GA has agr...        $164.6
# 32   Sabadell United Bank, National Association, Mi...      $1,700.0
# 33   Capital Bank, National Association, Rockville,...         $46.8
# 35   Enterprise Bank & Trust, Clayton, MO has agree...        $538.1
# 36   Columbia State Bank, Tacoma, WA has agreed to ...        $548.6
# ..                                                 ...           ...
# 73   Citizens South Bank, Gastonia, NC has agreed t...        $110.7
# 74   Hamilton State Bank, Hoschton, GA has agreed t...        $330.2
# 75   City National Bank, Los Angeles, CA has agreed...        $144.9
# 76   Heartland Bank and Trust Company, Bloomington,...        $186.8
# 78   Advantage National Bank Group, Elk Grove Villa...        $163.1
# 79   Seaway Bank and Trust Company, Chicago, IL has...        $190.4
# 80   The Pauls Valley National Bank, Pauls Valley, ...         $90.2
# 82   First State Bank, Mendota, IL has agreed to as...        $123.8
# 83   First California Bank, Westlake Village, CA ha...        $332.6
# 84   Bank of Marin, Novato, CA has agreed to assume...        $120.8
# 85   Heritage Bank of the South, Albany, GA has agr...        $214.3
# 86   SCBT National Association, Orangeburg, SC has ...        $387.6
# 87   Pacific Premier Bank, Costa Mesa, CA has agree...        $210.9
# 88   Royal Bank, Elroy, WI has agreed to assume all...         $83.8
# 89   First Michigan Bank, Troy, MI has agreed to as...        $390.5
# 90   Premier American Bank, National Association, M...        $125.5
# 91   Northbrook Bank & Trust Company, Northbrook, I...         $51.1
# 92   BankSouth, Greensboro, GA has agreed to assume...        $153.2
# 93   Renasant Bank, Tupelo, MS has agreed to assume...        $238.2
# 95   U.S. Bank, National Association, Minneapolis, ...      $2,310.0
# 96   To protect the insured depositors, the FDIC cr...        $781.5
# 97   McFarland State Bank, McFarland, WI has agreed...        $246.5
# 98   Bank 7, Oklahoma City, OK has agreed to assume...         $43.5
# 99   First-Citizens Bank & Trust Co., Raleigh, NC h...      $2,050.0
# 100  First Bank, Troy, NC has agreed to assume all ...        $195.1
# 101  CertusBank, National Association, Charlotte, N...        $440.6
# 102  To protect the insured depositors, the FDIC cr...        $100.9
# 103  Bank of the Ozarks, Little Rock, AR has agreed...        $230.6
# 104  Enterprise Bank & Trust, Clayton, MO has agree...        $150.6
# 105  First Southern Bank, Boca Raton, FL has agreed...        $598.5
#
#     approx_deposit                                          bank_name  \
# 2           $144.5                 Western National Bank, Phoenix, AZ
# 3           $112.1  Premier Community Bank of the Emerald Coast, C...
# 5           $347.7              Central Progressive Bank, Lacombe, LA
# 6            $82.0                     Polk County Bank, Johnston, IA
# 7            $55.9           Community Bank of Rockmart, Rockmart, GA
# 8           $169.1                    SunFirst Bank, Saint George, UT
# 9           $105.5                     Mid City Bank, Inc., Omaha, NE
# 11           $33.4                 All American Bank, Des Plaines, IL
# 12        $1,330.0  Community Banks of Colorado, Greenwood Village...
# 13          $166.2              Community Capital Bank, Jonesboro, GA
# 14          $179.2                    Decatur First Bank, Decatur, GA
# 15          $217.8                    Old Harbor Bank, Clearwater, FL
# 16          $167.5                            Country Bank, Aledo, IL
# 17          $201.2                     First State Bank, Cranford, NJ
# 18          $158.7       Blue Ridge Savings Bank, Inc., Asheville, NC
# 19          $181.4                  Piedmont Community Bank, Gray, GA
# 20          $290.4                   Sun Security Bank, Ellington, MO
# 21          $379.3                         The RiverBank, Wyoming, MN
# 23          $208.8                First International Bank, Plano, TX
# 24          $253.1  Citizens Bank of Northern California, Nevada C...
# 25          $901.8              Bank of the Commonwealth, Norfolk, VA
# 26          $280.1     The First National Bank Of Florida, Milton, FL
# 27           $96.6                      CreekSide Bank, Woodstock, GA
# 28          $111.2               Patriot Bank of Georgia, Cumming, GA
# 30          $137.2                      First Choice Bank, Geneva, IL
# 31          $159.7       First Southern National Bank, Statesboro, GA
# 32        $1,240.0                Lydian Private Bank, Palm Beach, FL
# 33           $45.8         Public Savings Bank, Huntingdon Valley, PA
# 35          $524.3      The First National Bank of Olathe, Olathe, KS
# 36          $515.7                        Bank of Whitman, Colfax, WA
# ..             ...                                                ...
# 73          $106.1                New Horizons Bank, East Ellijay, GA
# 74          $304.1               Bartow County Bank, Cartersville, GA
# 75          $136.4                Nevada Commerce Bank, Las Vegas, NV
# 76          $181.9  Western Springs National Bank and Trust, Weste...
# 78          $161.4                The Bank of Commerce, Wood Dale, IL
# 79          $183.3                         Legacy Bank, Milwaukee, WI
# 80           $68.3        The First National Bank of Davis, Davis, OK
# 82          $124.2             Valley Community Bank, St. Charles, IL
# 83          $272.2      San Luis Trust Bank, FSB, San Luis Obispo, CA
# 84          $105.3                         Charter Oak Bank, Napa, CA
# 85          $206.5        Citizens Bank of Effingham, Springfield, GA
# 86          $339.9                   Habersham Bank, Clarkesville, GA
# 87          $205.3             Canyon National Bank, Palm Springs, CA
# 88           $78.5                   Badger State Bank, Cassville, WI
# 89          $389.9                  Peoples State Bank, Hamtramck, MI
# 90          $116.7     Sunshine State Community Bank, Port Orange, FL
# 91           $49.5        Community First Bank - Chicago, Chicago, IL
# 92          $139.7               North Georgia Bank, Watkinsville, GA
# 93          $222.2                   American Trust Bank, Roswell, GA
# 95        $1,940.0                     First Community Bank, Taos, NM
# 96          $722.8                      FirsTier Bank, Louisville, CO
# 97          $195.2                Evergreen State Bank, Stoughton, WI
# 98           $40.3                  The First State Bank, Camargo, OK
# 99        $1,650.0                    United Western Bank, Denver, CO
# 100         $188.3               The Bank of Asheville, Asheville, NC
# 101         $402.4          CommunitySouth Bank and Trust, Easley, SC
# 102          $95.5          Enterprise Banking Company, McDonough, GA
# 103         $212.7                     Oglethorpe Bank, Brunswick, GA
# 104         $125.9                        Legacy Bank, Scottsdale, AZ
# 105         $529.6      First Commercial Bank of Florida, Orlando, FL
#
#            closing_date
# 2     December 16, 2011
# 3     December 16, 2011
# 5     November 18, 2011
# 6     November 18, 2011
# 7     November 10, 2011
# 8      November 4, 2011
# 9      November 4, 2011
# 11     October 28, 2011
# 12     October 21, 2011
# 13     October 21, 2011
# 14     October 21, 2011
# 15     October 21, 2011
# 16     October 14, 2011
# 17     October 14, 2011
# 18     October 14, 2011
# 19     October 14, 2011
# 20      October 7, 2011
# 21      October 7, 2011
# 23   September 30, 2011
# 24   September 23, 2011
# 25   September 23, 2011
# 26    September 9, 2011
# 27    September 2, 2011
# 28    September 2, 2011
# 30      August 19, 2011
# 31      August 19, 2011
# 32      August 19, 2011
# 33      August 18, 2011
# 35      August 12, 2011
# 36       August 5, 2011
# ..                  ...
# 73       April 15, 2011
# 74       April 15, 2011
# 75        April 8, 2011
# 76        April 8, 2011
# 78       March 25, 2011
# 79       March 11, 2011
# 80       March 11, 2011
# 82    February 25, 2011
# 83    February 18, 2011
# 84    February 18, 2011
# 85    February 18, 2011
# 86    February 18, 2011
# 87    February 11, 2011
# 88    February 11, 2011
# 89    February 11, 2011
# 90    February 11, 2011
# 91     February 4, 2011
# 92     February 4, 2011
# 93     February 4, 2011
# 95     January 28, 2011
# 96     January 28, 2011
# 97     January 28, 2011
# 98     January 28, 2011
# 99     January 21, 2011
# 100    January 21, 2011
# 101    January 21, 2011
# 102    January 21, 2011
# 103    January 14, 2011
# 104     January 7, 2011
# 105     January 7, 2011
#
# [92 rows x 5 columns]

# %% [markdown]
# ## 2012

# %%
# find historical data for 2012
year12 = driver.find_elements_by_class_name('yr-button')[11]
year12.click()

# %%
# favorite table
table_rows = driver.find_elements_by_tag_name("tbody")[20].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2012 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2012['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2012['approx_assets'] = approx_assets
        info2012['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2012['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2012['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2012)
print(info2012)
# Out:
# {'bank_name': 'Central Florida State Bank, Belleview, FL', 'approx_assets': '$79.1', 'approx_deposit': '$77.7', 'acquirer': 'CenterState Bank of Florida, National Association, has agreed to assume all deposits excluding certain brokered deposits.', 'closing_date': 'January 20, 2012'}

# %%
df_2012 = pd.DataFrame(rows)

# %%
df_2012.dropna(inplace=True)
df_2012
# Out:
#                                              acquirer approx_assets  \
# 2   Bank of Sullivan has agreed to assume all depo...         $42.8
# 4   CertusBank, National Association has agreed to...        $124.6
# 5   Heartland Bank and Trust Company has agreed to...        $924.0
# 6   Centennial Bank has agreed to assume all depos...        $225.5
# 8   The FDIC has approved the payout of the insure...        $483.0
# 9   Simmons First National Bank has agreed to assu...        $200.6
# 10  Stearns Bank National Association, has agreed ...         $67.2
# 11       SmartBank has agreed to assume all deposits.        $159.1
# 13  Old Plank Trail Community Bank, National Assoc...        $328.4
# 14  Simmons First National Bank has agreed to assu...        $282.3
# 15  Republic Bank & Trust Company has agreed to as...        $215.9
# 17  First Midwest Bank has agreed to assume all de...         $88.9
# 19  Stearns Bank National Association, has agreed ...        $216.7
# 20  Hinsdale Bank & Trust Company has agreed to as...        $199.1
# 21    Metcalf Bank has agreed to assume all deposits.        $110.0
# 22  Community & Southern Bank has agreed to assume...        $222.7
# 23  Community & Southern Bank has agreed to assume...        $119.8
# 24  First National Bank of the Gulf Coast has agre...         $87.0
# 25  Regional Missouri Bank has agreed to assume al...         $24.8
# 26  Ameris Bank has agreed to assume all deposits ...        $173.6
# 28  Clayton Bank and Trust has agreed to assume al...        $163.9
# 29   Fidelity Bank has agreed to assume all deposits.        $151.0
# 30  Harbor Community Bank has agreed to assume all...        $169.5
# 31  First Community Bank has agreed to assume all ...        $533.1
# 32  First State Bank has agreed to assume all depo...         $43.1
# 33  Bank of North Carolina has agreed to assume al...         $54.4
# 34      F & M Bank has agreed to assume all deposits.         $46.1
# 36  Southern States Bank has agreed to assume all ...         $51.6
# 37     Banesco USA has agreed to assume all deposits.        $101.0
# 39  Pacific Premier Bank has agreed to assume all ...        $125.8
# 40  First Federal Bank has agreed to assume all de...        $486.4
# 41  Great Southern Bank has agreed to assume all d...        $481.6
# 42        Sonabank has agreed to assume all deposits.        $164.3
# 43  To protect the insured depositors, the FDIC cr...        $166.7
# 44       Alma Bank has agreed to assume all deposits.         $51.9
# 46  The Huntington National Bank has agreed to ass...        $818.2
# 47  Stearns Bank National Association, has agreed ...         $95.7
# 48  International Bank of Chicago has agreed to as...        $268.7
# 49  The FDIC has approved the payout of the insure...         $71.2
# 50  Metro City Bank has agreed to assume all depos...        $143.7
# 52  The FDIC has approved the payout of the insure...        $434.1
# 53     Ameris Bank has agreed to assume all deposits.        $278.9
# 54  First Merchants Bank, National Association has...        $182.6
# 55  Barrington Bank & Trust Company, National Asso...         $93.9
# 57  U.S. Bank National Association, has agreed to ...        $272.6
# 58  First Resource Bank has agreed to assume all d...        $111.3
# 59  Republic Bank & Trust Company has agreed to as...      $1,185.0
# 60  CenterState Bank of Florida, National Associat...        $377.9
# 61  Capital Bank, National Association, has agreed...         $19.6
# 62  Hamilton State Bank has agreed to assume all d...        $536.9
# 63  CenterState Bank of Florida, National Associat...         $79.1
#
#    approx_deposit                                          bank_name  \
# 2           $41.9    Community Bank of the Ozarks, Sunrise Beach, MO
# 4          $108.9             Hometown Community Bank, Braselton, GA
# 5          $869.4        Citizens First National Bank, Princeton, IL
# 6          $223.3                 Heritage Bank of Florida, Lutz, FL
# 8          $432.2                              NOVA Bank, Berwyn, PA
# 9          $187.4                            Excel Bank, Sedalia, MO
# 10          $65.9          First East Side Savings Bank, Tamarac, FL
# 11         $151.1                 GulfSouth Private Bank, Destin, FL
# 13         $316.9                       First United Bank, Crete, IL
# 14         $245.7                       Truman Bank, Saint Louis, MO
# 15         $206.8             First Commercial Bank, Bloomington, MN
# 17          $77.5                Waukegan Savings Bank, Waukegan, IL
# 19         $213.1                 Jasper Banking Company, Jasper, GA
# 20         $175.9  Second Federal Savings and Loan Association of...
# 21         $102.6                        Heartland Bank, Leawood, KS
# 22         $193.3           First Cherokee State Bank, Woodstock, GA
# 23         $117.4                     Georgia Trust Bank, Buford, GA
# 24          $85.1         The Royal Palm Bank of Florida, Naples, FL
# 25          $24.2                  Glasgow Savings Bank, Glasgow, MO
# 26         $164.4                 Montgomery Bank & Trust, Ailey, GA
# 28         $156.4       The Farmers Bank of Lynchburg, Lynchburg, TN
# 29         $147.9               Security Exchange Bank, Marietta, GA
# 30         $160.0                     Putnam State Bank, Palatka, FL
# 31         $472.7                      Waccamaw Bank, Whiteville, NC
# 32          $42.3       Farmers and Traders State Bank, Shabbona, IL
# 33          $53.1      Carolina Federal Savings Bank, Charleston, SC
# 34          $44.8                 First Capital Bank, Kingfisher, OK
# 36          $45.1  Alabama Trust Bank, National Association, Syla...
# 37          $99.1  Security Bank, National Association, North Lau...
# 39         $122.8         Palm Desert National Bank, Palm Desert, CA
# 40         $440.5        Plantation Federal Bank, Pawleys Island, SC
# 41         $473.0  Inter Savings Bank, fsb D/B/A InterBank, fsb, ...
# 42         $145.5         HarVest Bank of Maryland, Gaithersburg, MD
# 43         $154.5           Bank of the Eastern Shore, Cambridge, MD
# 44          $50.7   Fort Lee Federal Savings Bank, FSB, Fort Lee, NJ
# 46         $747.6                        Fidelity Bank, Dearborn, MI
# 47          $90.6             Covenant Bank & Trust, Rock Spring, GA
# 48         $199.0                         Premier Bank, Wilmette, IL
# 49          $72.4                         New City Bank, Chicago, IL
# 50         $116.8                Global Commerce Bank, Doraville, GA
# 52         $432.2          Home Savings of America, Little Falls, MN
# 53         $266.6             Central Bank of Georgia, Ellaville, GA
# 54         $171.6                          SCB Bank, Shelbyville, IN
# 55          $89.5  Charter National Bank and Trust, Hoffman Estat...
# 57         $268.8                            BankEast, Knoxville, TN
# 58         $108.3            Patriot Bank Minnesota, Forest Lake, MN
# 59       $1,156.0              Tennessee Commerce Bank, Franklin, TN
# 60         $349.5  First Guaranty Bank and Trust Company of Jacks...
# 61          $17.7          American Eagle Savings Bank, Boothwyn, PA
# 62         $527.5              The First State Bank, Stockbridge, GA
# 63          $77.7          Central Florida State Bank, Belleview, FL
#
#           closing_date
# 2    December 14, 2012
# 4    November 16, 2012
# 5     November 2, 2012
# 6     November 2, 2012
# 8     October 26, 2012
# 9     October 19, 2012
# 10    October 19, 2012
# 11    October 19, 2012
# 13  September 28, 2012
# 14  September 14, 2012
# 15   September 7, 2012
# 17      August 3, 2012
# 19       July 27, 2012
# 20       July 20, 2012
# 21       July 20, 2012
# 22       July 20, 2012
# 23       July 20, 2012
# 24       July 20, 2012
# 25       July 13, 2012
# 26        July 6, 2012
# 28       June 15, 2012
# 29       June 15, 2012
# 30       June 15, 2012
# 31        June 8, 2012
# 32        June 8, 2012
# 33        June 8, 2012
# 34        June 8, 2012
# 36        May 18, 2012
# 37         May 4, 2012
# 39      April 27, 2012
# 40      April 27, 2012
# 41      April 27, 2012
# 42      April 27, 2012
# 43      April 27, 2012
# 44      April 20, 2012
# 46      March 30, 2012
# 47      March 23, 2012
# 48      March 23, 2012
# 49       March 9, 2012
# 50       March 2, 2012
# 52   February 24, 2012
# 53   February 24, 2012
# 54   February 10, 2012
# 55   February 10, 2012
# 57    January 27, 2012
# 58    January 27, 2012
# 59    January 27, 2012
# 60    January 27, 2012
# 61    January 20, 2012
# 62    January 20, 2012
# 63    January 20, 2012

# %% [markdown]
# ## 2013

# %%
# find historical data for 2013
year13 = driver.find_elements_by_class_name('yr-button')[12]
year13.click()

# %%
# favorite table
table_rows = driver.find_elements_by_tag_name("tbody")[22].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2013 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2013['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2013['approx_assets'] = approx_assets
        info2013['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2013['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2013['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2013)
print(info2013)
# Out:
# {'bank_name': 'Westside Community Bank, University Place, WA', 'approx_assets': '$97.7', 'approx_deposit': '$96.5', 'acquirer': 'Sunwest Bank has agreed to assume all deposits.', 'closing_date': 'January 11, 2013'}

# %%
df_2013 = pd.DataFrame(rows)

# %%
df_2013.dropna(inplace=True)
df_2013
# Out:
#                                              acquirer approx_assets  \
# 2   Spirit of Texas Bank, SSB has agreed to assume...        $160.1
# 4   First Federal Bank of Florida has agreed to as...         $25.5
# 6   PlainsCapital Bank has agreed to assume all de...      $3,100.0
# 7   The FDIC has approved the payout of the insure...         $26.3
# 9   First Fidelity Bank, National Association has ...        $202.2
# 10  CB&S Bank, Inc. has agreed to assume all depos...        $386.9
# 11  Nicolet National Bank has agreed to assume all...         $43.6
# 12         C1 Bank has agreed to assume all deposits.        $265.7
# 14  First Tennessee Bank, National Association has...        $437.3
# 15      Plaza Bank has agreed to assume all deposits.         $20.2
# 17  North Shore Bank, FSB has agreed to assume all...        $134.0
# 18  Western State Bank has agreed to assume all de...         $31.6
# 19    Synovus Bank has agreed to assume all deposits.         $60.8
# 20  Capital Bank, N.A. has agreed to assume all de...         $21.9
# 22  Hamilton State Bank has agreed to assume all d...        $316.5
# 23  CertusBank, National Association has agreed to...        $108.6
# 24  First Federal Bank of Florida has agreed to as...         $39.2
# 25  FirstAtlantic Bank has agreed to assume all de...        $110.9
# 26  Your Community Bank has agreed to assume all d...        $100.1
# 27  First Scottsdale Bank, National Association, h...         $45.2
# 29  HeritageBank of the South has agreed to assume...        $258.8
# 31  Liberty Bank and Trust Company has agreed to a...         $58.4
# 33  First Minnesota Bank has agreed to assume all ...         $50.2
# 34    Sunwest Bank has agreed to assume all deposits.         $97.7
#
#    approx_deposit                                          bank_name  \
# 2          $142.6  Texas Community Bank, National Association, Th...
# 4           $25.0             Bank of Jackson County, Graceville, FL
# 6        $2,300.0                  First National Bank, Edinburg, TX
# 7           $25.7               The Community's Bank, Bridgeport, CT
# 9          $196.9               Sunrise Bank of Arizona, Phoenix, AZ
# 10         $377.7                  Community South Bank, Parsons, TN
# 11          $40.7                         Bank of Wausau, Wausau, WI
# 12         $254.2  First Community Bank of Southwest Florida, For...
# 14         $373.4            Mountain National Bank, Sevierville, TN
# 15          $19.6             1st Commerce Bank, North Las Vegas, NV
# 17         $127.6  Banks of Wisconsin, which did business as Bank...
# 18          $30.8               Central Arizona Bank, Scottsdale, AZ
# 19          $57.8                         Sunrise Bank, Valdosta, GA
# 20          $21.2               Pisgah Community Bank, Asheville, NC
# 22         $314.3              Douglas County Bank, Douglasville, GA
# 23         $103.7                           Parkway Bank, Lenoir, NC
# 24          $37.6               Chipola Community Bank, Marianna, FL
# 25         $108.5    Heritage Bank of North Florida, Orange Park, FL
# 26          $93.9                  First Federal Bank, Lexington, KY
# 27          $44.2                  Gold Canyon Bank, Gold Canyon, AZ
# 29         $224.1                        Frontier Bank, LaGrange, GA
# 31          $54.2                         Covenant Bank, Chicago, IL
# 33          $49.1                      1st Regents Bank, Andover, MN
# 34          $96.5      Westside Community Bank, University Place, WA
#
#           closing_date
# 2    December 13, 2013
# 4     October 30, 2013
# 6   September 13, 2013
# 7   September 13, 2013
# 9      August 23, 2013
# 10     August 23, 2013
# 11      August 9, 2013
# 12      August 2, 2013
# 14        June 7, 2013
# 15        June 6, 2013
# 17        May 31, 2013
# 18        May 14, 2013
# 19        May 10, 2013
# 20        May 10, 2013
# 22      April 26, 2013
# 23      April 26, 2013
# 24      April 19, 2013
# 25      April 19, 2013
# 26      April 19, 2013
# 27       April 5, 2013
# 29       March 8, 2013
# 31   February 15, 2013
# 33    January 18, 2013
# 34    January 11, 2013

# %% [markdown]
# ## 2014

# %%
# find historical data for 2014
year14 = driver.find_elements_by_class_name('yr-button')[13]
year14.click()

# %%
# favorite table
table_rows = driver.find_elements_by_tag_name("tbody")[24].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2014 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2014['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2014['approx_assets'] = approx_assets
        info2014['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2014['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2014['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2014)
print(info2014)
# Out:
# {'bank_name': 'DuPage National Bank, West Chicago, IL', 'approx_assets': '$61.7', 'approx_deposit': '$59.6', 'acquirer': 'Republic Bank of Chicago has agreed to assume all deposits.', 'closing_date': 'January 17, 2014'}

# %%
df_2014 = pd.DataFrame(rows)

# %%
df_2014.dropna(inplace=True)
df_2014
# Out:
#                                              acquirer approx_assets  \
# 2        BankVista has agreed to assume all deposits.         $18.8
# 4   Bank of Southern California, N.A. has agreed t...         $86.4
# 6   State Bank of Texas has agreed to assume all d...        $954.4
# 7      Howard Bank has agreed to assume all deposits.        $188.2
# 9   Providence Bank, LLC has agreed to assume all ...         $72.9
# 10  Community & Southern Bank has agreed to assume...        $169.0
# 12  Alva State Bank & Trust Company has agreed to ...         $22.8
# 13  Landmark Bank, National Association has agreed...         $81.8
# 14  Great Southern Bank has agreed to assume all d...        $456.4
# 16   Bay Bank, FSB has agreed to assume all deposits.        $140.1
# 17  United Fidelity Bank, fsb has agreed to assume...         $36.5
# 18  Republic Bank of Chicago has agreed to assume ...         $66.3
# 20  Palmetto State Bank has agreed to assume all d...         $54.5
# 22  First Choice Bank has agreed to assume all dep...         $63.5
# 23  WashingtonFirst Bank has agreed to assume all ...        $130.3
# 25  Sunwest Bank has agreed to assume all deposits...        $153.4
# 26  BancFirst has agreed to assume all deposits ex...        $331.4
# 27  Republic Bank of Chicago has agreed to assume ...         $61.7
#
#    approx_deposit                                          bank_name  \
# 2           $18.2                    Northern Star Bank, Mankato, MN
# 4           $82.1  Frontier Bank, FSB, D/B/A El Paseo Bank, Palm ...
# 6          $915.3  The National Republic Bank of Chicago, Chicago...
# 7          $183.1                     NBRS Financial, Rising Sun, MD
# 9           $71.0                 GreenChoice Bank, fsb, Chicago, IL
# 10         $161.6              Eastside Commercial Bank, Conyers, GA
# 12          $20.9                The Freedom State Bank, Freedom, OK
# 13          $66.5                   Valley Bank, Fort Lauderdale, FL
# 14         $360.0                            Valley Bank, Moline, IL
# 16         $111.1           Slavie Federal Savings Bank, Bel Air, MD
# 17          $29.5              Columbia Savings Bank, Cincinnati, OH
# 18          $65.0                      AztecAmerica Bank, Berwyn, IL
# 20          $51.0                 Allendale County Bank, Fairfax, SC
# 22          $62.5                    Vantage Point Bank, Horsham, PA
# 23         $121.7  Millennium Bank, National Association, Sterlin...
# 25         $145.1                            Syringa Bank, Boise, ID
# 26         $328.8                     The Bank of Union, El Reno, OK
# 27          $59.6             DuPage National Bank, West Chicago, IL
#
#          closing_date
# 2   December 19, 2014
# 4    November 7, 2014
# 6    October 24, 2014
# 7    October 17, 2014
# 9       July 25, 2014
# 10      July 18, 2014
# 12      June 27, 2014
# 13      June 20, 2014
# 14      June 20, 2014
# 16       May 30, 2014
# 17       May 23, 2014
# 18       May 16, 2014
# 20     April 25, 2014
# 22  February 28, 2014
# 23  February 28, 2014
# 25   January 31, 2014
# 26   January 24, 2014
# 27   January 17, 2014

# %% [markdown]
# ## 2015

# %%
# find historical data for 2015
year15 = driver.find_elements_by_class_name('yr-button')[14]
year15.click()

# %%
# favorite table
table_rows = driver.find_elements_by_tag_name("tbody")[26].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2015 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2015['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2015['approx_assets'] = approx_assets
        info2015['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2015['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2015['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2015)
print(info2015)
# Out:
# {'bank_name': 'First National Bank of Crestview, Crestview, FL', 'approx_assets': '$79.7', 'approx_deposit': '$78.6', 'acquirer': 'First NBC Bank has agreed to assume all deposits.', 'closing_date': 'January 16, 2015'}

# %%
df_2015 = pd.DataFrame(rows)

# %%
df_2015.dropna(inplace=True)
df_2015
# Out:
#                                              acquirer approx_assets  \
# 2   Twin City Bank has agreed to assume all deposits.          $4.9
# 3    Fidelity Bank has agreed to assume all deposits.        $294.2
# 5   United Fidelity Bank, fsb has agreed to assume...         $31.7
# 7   Republic Bank of Chicago has agreed to assume ...         $90.0
# 9   Banco Popular de Puerto Rico, Hato Rey, PR has...      $5,900.0
# 10  First-Citizens Bank & Trust Company has agreed...        $272.3
# 12  United Fidelity Bank, fsb has agreed to assume...         $54.7
# 13  First NBC Bank has agreed to assume all deposits.         $79.7
#
#    approx_deposit                                        bank_name  \
# 2            $4.7             Hometown National Bank, Longview, WA
# 3          $280.7          The Bank of Georgia, Peachtree City, GA
# 5           $29.6                         Premier Bank, Denver, CO
# 7           $90.0                      Edgebrook Bank, Chicago, IL
# 9        $4,100.0                         Doral Bank, San Juan, PR
# 10         $262.7   Capitol City Bank & Trust Company, Atlanta, GA
# 12          $53.5             Highland Community Bank, Chicago, IL
# 13          $78.6  First National Bank of Crestview, Crestview, FL
#
#          closing_date
# 2     October 2, 2015
# 3     October 2, 2015
# 5       July 10, 2015
# 7         May 8, 2015
# 9   February 27, 2015
# 10  February 13, 2015
# 12   January 23, 2015
# 13   January 16, 2015

# %% [markdown]
# ## 2016

# %%
# find historical data for 2016
year16 = driver.find_elements_by_class_name('yr-button')[15]
year16.click()

# %%
# favorite table
table_rows = driver.find_elements_by_tag_name("tbody")[28].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2016 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2016['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2016['approx_assets'] = approx_assets
        info2016['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2016['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2016['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2016)
print(info2016)
# Out:
# {'bank_name': 'North Milwaukee State Bank, Milwaukee, WI', 'approx_assets': '$67.1', 'approx_deposit': '$61.5', 'acquirer': 'First-Citizens Bank & Trust Company has agreed to assume all deposits excluding certain brokered deposits.', 'closing_date': 'March 11, 2016'}

# %%
df_2016 = pd.DataFrame(rows)

# %%
df_2016.dropna(inplace=True)
df_2016
# Out:
#                                              acquirer approx_assets  \
# 2     Today's Bank has agreed to assume all deposits.         $66.3
# 4      United Bank has agreed to assume all deposits.         $21.4
# 6   First-Citizens Bank & Trust Company has agreed...        $103.3
# 8   The Bank of Fayette County has agreed to assum...         $20.7
# 10  First-Citizens Bank & Trust Company has agreed...         $67.1
#
#    approx_deposit                                    bank_name  \
# 2           $64.7                    Allied Bank, Mulberry, AR
# 4           $21.1   The Woodbury Banking Company, Woodbury, GA
# 6          $101.0  First CornerStone Bank, King of Prussia, PA
# 8           $20.3              Trust Company Bank, Memphis, TN
# 10          $61.5    North Milwaukee State Bank, Milwaukee, WI
#
#           closing_date
# 2   September 23, 2016
# 4      August 19, 2016
# 6          May 6, 2016
# 8       April 29, 2016
# 10      March 11, 2016

# %% [markdown]
# ## 2017

# %%
# find historical data for 2017
year17 = driver.find_elements_by_class_name('yr-button')[16]
year17.click()

# %%
# favorite table
table_rows = driver.find_elements_by_tag_name("tbody")[30].find_elements_by_tag_name("tr")
# for row in table_rows:
#     print(row.text)

# %%
# get bank name, financial info of acquisition, and acquirer info

rows = []
for row in table_rows:
    info2017 = {}


    try:
        # bank name
        name = row.find_element_by_tag_name("a").text
        info2017['bank_name'] = name
        
        # financial info for the acquisition
        approx_assets = row.find_element_by_class_name("numcol").text
        approx_deposit = row.find_elements_by_class_name("numcol")[1].text
        info2017['approx_assets'] = approx_assets
        info2017['approx_deposit'] = approx_deposit
        
        # acquirer info, which warrants some extreme regex
        info2017['acquirer'] = row.find_elements_by_tag_name("td")[5].text
        info2017['closing_date'] = row.find_elements_by_tag_name("td")[2].text

    except:
        pass
    
    rows.append(info2017)
print(info2017)
# Out:
# {'bank_name': 'Harvest Community Bank, Pennsville, NJ', 'approx_assets': '$126.4', 'approx_deposit': '$123.8', 'acquirer': 'First-Citizens Bank & Trust Company has agreed to assume all deposits.', 'closing_date': 'January 13, 2017'}

# %%
df_2017 = pd.DataFrame(rows)

# %%
df_2017.dropna(inplace=True)
df_2017
# Out:
#                                              acquirer approx_assets  \
# 2   Royal Savings Bank has agreed to assume the no...        $166.3
# 4      Conway Bank has agreed to assume all deposits.         $34.2
# 6   United Fidelity Bank, fsb has agreed to assume...         $34.4
# 7   First-Citizens Bank & Trust Company has agreed...      $1,000.0
# 9   Whitney Bank has agreed to assume the transact...      $4,740.0
# 11  Cache Valley Bank has agreed to assume all dep...         $68.2
# 13  State Bank of Texas has agreed to assume all d...        $361.2
# 14  First-Citizens Bank & Trust Company has agreed...        $126.4
#
#    approx_deposit                                          bank_name  \
# 2          $144.0   Washington Federal Bank for Savings, Chicago, IL
# 4           $29.6  The Farmers and Merchants State Bank of Argoni...
# 6           $34.0                Fayette County Bank, Saint Elmo, IL
# 7        $1,000.0  Guaranty Bank, Milwaukee, WI, (d/b/a BestBank ...
# 9        $3,540.0                    First NBC Bank, New Orleans, LA
# 11          $65.0              Proficio Bank, Cottonwood Heights, UT
# 13         $307.1         Seaway Bank and Trust Company, Chicago, IL
# 14         $123.8             Harvest Community Bank, Pennsville, NJ
#
#          closing_date
# 2   December 15, 2017
# 4    October 13, 2017
# 6        May 26, 2017
# 7         May 5, 2017
# 9      April 28, 2017
# 11      March 3, 2017
# 13   January 27, 2017
# 14   January 13, 2017

# %% [markdown]
# ## 2018 - no failures so far.

# %%
df = pd.read_csv('banklist.csv')
df['year'] = pd.to_datetime(df['Closing Date'])
df['year'] = df['year'].dt.strftime('%Y')
df['fail_date'] = pd.to_datetime(df['Closing Date'], format='%d-%b-%y')
df.head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date  year  \
# 0                   Royal Savings Bank    15-Dec-17    21-Feb-18  2017
# 1                          Conway Bank    13-Oct-17    21-Feb-18  2017
# 2            United Fidelity Bank, fsb    26-May-17    26-Jul-17  2017
# 3  First-Citizens Bank & Trust Company     5-May-17    22-Mar-18  2017
# 4                         Whitney Bank    28-Apr-17     5-Dec-17  2017
#
#    fail_date
# 0 2017-12-15
# 1 2017-10-13
# 2 2017-05-26
# 3 2017-05-05
# 4 2017-04-28

# %%
df_2001
# Out:
#                                             acquirer approx_assets  \
# 2  Delta Trust and Bank, Parkdale, AR agreed to a...         $30.7
# 4  The Federal Deposit Insurance Corporation toda...      $2,300.0
# 6  North Valley Bank, Zanesville, OH agreed to as...          $9.5
# 8  Southern New Hampshire Bank and Trust Company,...         $18.4
#
#   approx_deposit                                          bank_name  \
# 2          $25.7               Sinclair National Bank, Gravette, AR
# 4       $1,600.0                   Superior Bank, FSB, Hinsdale, IL
# 6           $8.8                  The Malta National Bank, Malta,OH
# 8          $17.5  First Alliance Bank & Trust Company, Mancheste...
#
#         closing_date
# 2  September 7, 2001
# 4      July 27, 2001
# 6        May 3, 2001
# 8   February 2, 2001

# %%
df_2001['bank_name'] = df_2001.bank_name.str.split(",").str[0]
# df_2001

# %%
df_2002['bank_name'] = df_2002.bank_name.str.split(",").str[0]
# df_2002

# %%
df_2003['bank_name'] = df_2003.bank_name.str.split(",").str[0]
# df_2003

# %%
df_2004['bank_name'] = df_2004.bank_name.str.split(",").str[0]
# df_2004

# %%
df_2007['bank_name'] = df_2007.bank_name.str.split(",").str[0]
# df_2007

# %%
df_2008['bank_name'] = df_2008.bank_name.str.split(",").str[0]
# df_2008

# %%
df_2009['bank_name'] = df_2009.bank_name.str.split(",").str[0]
# df_2009

# %%
df_2010['bank_name'] = df_2010.bank_name.str.split(",").str[0]
# df_2010

# %%
df_2011['bank_name'] = df_2011.bank_name.str.split(",").str[0]
# df_2011

# %%
df_2012['bank_name'] = df_2012.bank_name.str.split(",").str[0]
# df_2012

# %%
df_2013['bank_name'] = df_2013.bank_name.str.split(",").str[0]
# df_2013

# %%
df_2014['bank_name'] = df_2014.bank_name.str.split(",").str[0]
# df_2014

# %%
df_2015['bank_name'] = df_2015.bank_name.str.split(",").str[0]
# df_2015

# %%
df_2016['bank_name'] = df_2016.bank_name.str.split(",").str[0]
# df_2016

# %%
df_2017['bank_name'] = df_2017.bank_name.str.split(",").str[0]
# df_2017

# %%
df_new = pd.concat([df_2001, df_2002, df_2003, df_2004, df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017], sort=True)

# %%
df_new.to_csv('bank-financial-info.csv', index=False)
