# %%
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler

# %matplotlib inline

# %%
# graph styles
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'patch.linewidth': 0.5,
    'figure.facecolor': 'white',
    'font.size': 12.0,
    'axes.facecolor': 'white',
    'axes.edgecolor': 'white',
    'axes.linewidth': '1',
    'axes.grid': True,
    'grid.color': '#b7b7b7',
    'axes.titlesize': 'x-large',
    'axes.labelsize': 'large',
    'axes.axisbelow': True,
    'axes.prop_cycle': cycler('color', ['#64aad4', '#275876', '#ec866c', '#8bccc9', '#f9d669', '#EBA239']),
    'xtick.major.size': 0,
    'xtick.minor.size': 0,
    'ytick.major.size': 0,
    'ytick.minor.size': 0,
    'axes.labelweight': 'medium',
    'axes.spines.left': False,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
    'legend.facecolor': '#FFFFFF',
    'font.family': 'Gulim',
})


# # matplotlib counts from the bottom and builds up
# for i, bar in enumerate(ax.patches):
#     value = int(round(bar.get_width()))
#     x_pos = bar.get_width() - 1
#     y_pos = i
# #     ax.text(x_pos, y_pos, value, verticalalignment='center')
#     ax.text(x_pos, y_pos, value, va='center', ha='right', color='white', fontweight='bold')

# ax.set_xlabel("Average life expectancy")
# ax.set_ylabel("")
# ax.set_title("Europeans really know how to live [forever]", pad=20)
# ax.title.set_fontsize(14)

# %%
bias_motivation = pd.read_excel("Table_1_Incidents_Offenses_Victims_and_Known_Offenders_by_Bias_Motivation_2016.xls")
offense_type = pd.read_excel("Table_2_Incidents_Offenses_Victims_and_Known_Offenders_by_Offense_Type_2016.xls")
offender_race = pd.read_excel("Table_3_Offenses_Known_Offenders_Race_and_Ethnicity_by_Offense_Type_2016.xls")
location = pd.read_excel("Table_10_Incidents_Bias_Motivation_by_Location_2016.xls")

# %%
bias_motivation.head()
# Out:
#                                             Table 1  Unnamed: 1 Unnamed: 2  \
# 0  Incidents, Offenses, Victims, and Known Offenders        NaN        NaN
# 1                           by Bias Motivation, 2016        NaN        NaN
# 2                                    Bias motivation  Incidents   Offenses
# 3                                              Total       6121       7321
# 4                              Single-Bias Incidents       6063       7227
#
#   Unnamed: 3         Unnamed: 4  Unnamed: 5  Unnamed: 6 Unnamed: 7
# 0        NaN                NaN         NaN         NaN        NaN
# 1        NaN                NaN         NaN         NaN        NaN
# 2   Victims1  Known\noffenders2         NaN         NaN        NaN
# 3       7615               5770         NaN         NaN        NaN
# 4       7509               5727         NaN         NaN        NaN

# %%
offense_type.head()
# Out:
#                                            Table 2    Unnamed: 1 Unnamed: 2  \
# 0  Incidents, Offenses, Victims, and Known Offenders         NaN        NaN
# 1                              by Offense Type, 2016         NaN        NaN
# 2                                       Offense type  Incidents1   Offenses
# 3                                              Total        6121       7321
# 4                            Crimes against persons:        3765       4720
#
#   Unnamed: 3         Unnamed: 4  Unnamed: 5 Unnamed: 6
# 0        NaN                NaN         NaN        NaN
# 1        NaN                NaN         NaN        NaN
# 2   Victims2  Known\noffenders3         NaN        NaN
# 3       7615               5770         NaN        NaN
# 4       4720               4353         NaN        NaN

# %%
offender_race.drop([0,1,2,3, 23,24,25,26], inplace=True)

# %%
offender_race.columns = offender_race.iloc[0]
offender_race.drop([4,5], inplace=True)

# %%
offender_race.columns.values[0] = 'crime_type'
offender_race.columns.values[1] = 'totals'
offender_race.drop(columns='totals', inplace=True)

# %%
offender_race.rename(index=str, columns={"White": "white", 2: "black", 3: "native_amer", 4: "asian", 5: "native_hawaiian", 6: "multi_race_group", 7: "unknown", 8: "mult_ethnic_group"}, inplace=True)
offender_race
# Out:
# 4                             crime_type white Black or\nAfrican\nAmerican  \
# 6                Crimes against persons:  2197                        1117
# 7   Murder and nonnegligent manslaughter     4                           5
# 8             Rape (revised definition)2     9                           6
# 9              Rape (legacy definition)3     0                           0
# 10                    Aggravated assault   395                         268
# 11                        Simple assault   764                         513
# 12                          Intimidation  1015                         322
# 13                                Other4    10                           3
# 14              Crimes against property:   429                         194
# 15                               Robbery    25                          67
# 16                              Burglary    33                          11
# 17                         Larceny-theft    69                          33
# 18                   Motor vehicle theft     3                           3
# 19                                 Arson    13                           5
# 20          Destruction/damage/vandalism   267                          69
# 21                                Other4    19                           6
# 22               Crimes against society4    54                          20
#
# 4  American\nIndian or\nAlaska Native Asian  \
# 6                                  35    35
# 7                                   0     0
# 8                                   2     0
# 9                                   0     0
# 10                                  9     7
# 11                                 17     9
# 12                                  7    19
# 13                                  0     0
# 14                                 12     9
# 15                                  3     0
# 16                                  1     1
# 17                                  1     1
# 18                                  0     0
# 19                                  0     0
# 20                                  7     7
# 21                                  0     0
# 22                                  2     1
#
# 4  Native\nHawaiian\nor Other\nPacific\nIslander Group of\nmultiple\nraces  \
# 6                                              4                       199
# 7                                              0                         0
# 8                                              0                         0
# 9                                              0                         0
# 10                                             1                        63
# 11                                             3                        93
# 12                                             0                        43
# 13                                             0                         0
# 14                                             3                        45
# 15                                             0                        13
# 16                                             0                         3
# 17                                             0                         2
# 18                                             0                         1
# 19                                             0                         2
# 20                                             3                        24
# 21                                             0                         0
# 22                                             0                         1
#
# 4  Unknown\nrace Hispanic\nor\nLatino Not\nHispanic\nor\nLatino  \
# 6            505                  214                       856
# 7              0                    0                         1
# 8              3                    2                         2
# 9              0                    0                         0
# 10            56                   69                       179
# 11           184                   90                       377
# 12           262                   52                       288
# 13             0                    1                         9
# 14           504                   40                       153
# 15            11                   10                        30
# 16            18                    2                        12
# 17            33                    1                        21
# 18             4                    0                         0
# 19             4                    3                         3
# 20           422                   23                        85
# 21            12                    1                         2
# 22             1                    0                        17
#
# 4  Group of\nmultiple\nethnicities Unknown\nethnicity   NaN
# 6                               28               1880   628
# 7                                0                  3     0
# 8                                1                 14     4
# 9                                0                  0     0
# 10                               9                313    74
# 11                              14                654   104
# 12                               4                893   441
# 13                               0                  3     5
# 14                               8                564  1323
# 15                               1                 47    15
# 16                               2                 35    56
# 17                               1                101    92
# 18                               0                 11     9
# 19                               1                  7    15
# 20                               3                329  1114
# 21                               0                 34    22
# 22                               2                 60     3

# %%
offender_race = offender_race.infer_objects()
offender_race
# Out:
# 4                             crime_type  white  Black or\nAfrican\nAmerican  \
# 6                Crimes against persons:   2197                         1117
# 7   Murder and nonnegligent manslaughter      4                            5
# 8             Rape (revised definition)2      9                            6
# 9              Rape (legacy definition)3      0                            0
# 10                    Aggravated assault    395                          268
# 11                        Simple assault    764                          513
# 12                          Intimidation   1015                          322
# 13                                Other4     10                            3
# 14              Crimes against property:    429                          194
# 15                               Robbery     25                           67
# 16                              Burglary     33                           11
# 17                         Larceny-theft     69                           33
# 18                   Motor vehicle theft      3                            3
# 19                                 Arson     13                            5
# 20          Destruction/damage/vandalism    267                           69
# 21                                Other4     19                            6
# 22               Crimes against society4     54                           20
#
# 4   American\nIndian or\nAlaska Native  Asian  \
# 6                                   35     35
# 7                                    0      0
# 8                                    2      0
# 9                                    0      0
# 10                                   9      7
# 11                                  17      9
# 12                                   7     19
# 13                                   0      0
# 14                                  12      9
# 15                                   3      0
# 16                                   1      1
# 17                                   1      1
# 18                                   0      0
# 19                                   0      0
# 20                                   7      7
# 21                                   0      0
# 22                                   2      1
#
# 4   Native\nHawaiian\nor Other\nPacific\nIslander  Group of\nmultiple\nraces  \
# 6                                               4                        199
# 7                                               0                          0
# 8                                               0                          0
# 9                                               0                          0
# 10                                              1                         63
# 11                                              3                         93
# 12                                              0                         43
# 13                                              0                          0
# 14                                              3                         45
# 15                                              0                         13
# 16                                              0                          3
# 17                                              0                          2
# 18                                              0                          1
# 19                                              0                          2
# 20                                              3                         24
# 21                                              0                          0
# 22                                              0                          1
#
# 4   Unknown\nrace  Hispanic\nor\nLatino  Not\nHispanic\nor\nLatino  \
# 6             505                   214                        856
# 7               0                     0                          1
# 8               3                     2                          2
# 9               0                     0                          0
# 10             56                    69                        179
# 11            184                    90                        377
# 12            262                    52                        288
# 13              0                     1                          9
# 14            504                    40                        153
# 15             11                    10                         30
# 16             18                     2                         12
# 17             33                     1                         21
# 18              4                     0                          0
# 19              4                     3                          3
# 20            422                    23                         85
# 21             12                     1                          2
# 22              1                     0                         17
#
# 4   Group of\nmultiple\nethnicities  Unknown\nethnicity   NaN
# 6                                28                1880   628
# 7                                 0                   3     0
# 8                                 1                  14     4
# 9                                 0                   0     0
# 10                                9                 313    74
# 11                               14                 654   104
# 12                                4                 893   441
# 13                                0                   3     5
# 14                                8                 564  1323
# 15                                1                  47    15
# 16                                2                  35    56
# 17                                1                 101    92
# 18                                0                  11     9
# 19                                1                   7    15
# 20                                3                 329  1114
# 21                                0                  34    22
# 22                                2                  60     3

# %%
races = pd.read_excel("Table_5_Offenses_Known_Offenders_Race_and_Ethnicity_by_Bias_Motivation_2016.xls")

# %%
#races

# %%
races.drop([0,1,2,3, 5, 48, 49], inplace=True)

# %%
races.columns = races.iloc[0]
races.drop([4], inplace=True)

# %%
races.head()
# Out:
# 4                                     NaN   NaN White  \
# 6                   Single-Bias Incidents  7227  2661
# 7                Race/Ethnicity/Ancestry:  4229  1775
# 8                              Anti-White   876   133
# 9          Anti-Black or African American  2122  1142
# 10  Anti-American Indian or Alaska Native   161    56
#
# 4  Black or\nAfrican\nAmerican American\nIndian or\nAlaska Native Asian  \
# 6                         1307                                 49    45
# 7                          781                                 37    32
# 8                          452                                 20     6
# 9                           80                                  9    17
# 10                          28                                  2     0
#
# 4  Native\nHawaiian\nor Other\nPacific\nIslander Group\nof\nmultiple\nraces  \
# 6                                              7                        242
# 7                                              2                        150
# 8                                              0                         27
# 9                                              1                         88
# 10                                             0                          3
#
# 4  Unknown\nrace Hispanic\nor\nLatino Not\nHispanic\nor\nLatino  \
# 6            993                  252                       998
# 7            398                  135                       662
# 8             80                   22                       169
# 9            202                   82                       267
# 10            14                    1                         3
#
# 4  Group of\nmultiple\nethnicities Unknown\nethnicity   NaN  NaN  NaN
# 6                               38               2476  1923  NaN  NaN  NaN
# 7                               22               1618  1054  NaN  NaN  NaN
# 8                                9                393   158  NaN  NaN  NaN
# 9                                5                808   583  NaN  NaN  NaN
# 10                               0                 92    58  NaN  NaN  NaN

# %%
races.columns.values[0] = 'crime_type'
races.columns.values[1] = 'total'

# %%
races
# Out:
# 4                                          crime_type total White  \
# 6                               Single-Bias Incidents  7227  2661
# 7                            Race/Ethnicity/Ancestry:  4229  1775
# 8                                          Anti-White   876   133
# 9                      Anti-Black or African American  2122  1142
# 10              Anti-American Indian or Alaska Native   161    56
# 11                                         Anti-Asian   131    65
# 12     Anti-Native Hawaiian or Other Pacific Islander     9     4
# 13                         Anti-Multiple Races, Group   178    54
# 14                                          Anti-Arab    56    32
# 15                            Anti-Hispanic or Latino   449   228
# 16                 Anti-Other Race/Ethnicity/Ancestry   247    61
# 17                                          Religion:  1538   389
# 18                                        Anti-Jewish   834   156
# 19                                      Anti-Catholic    63     9
# 20                                    Anti-Protestant    20    11
# 21                              Anti-Islamic (Muslim)   381   135
# 22                                Anti-Other Religion    90    20
# 23                     Anti-Multiple Religions, Group    48    20
# 24                                        Anti-Mormon     8     2
# 25                             Anti-Jehovah's Witness     3     2
# 26      Anti-Eastern Orthodox (Russian, Greek, Other)    28    15
# 27                               Anti-Other Christian    37     4
# 28                                      Anti-Buddhist     1     0
# 29                                         Anti-Hindu    12     9
# 30                                          Anti-Sikh     7     4
# 31                      Anti-Atheism/Agnosticism/etc.     6     2
# 32                                Sexual Orientation:  1218   414
# 33                                    Anti-Gay (Male)   765   257
# 34                                       Anti-Lesbian   141    51
# 35  Anti-Lesbian, Gay, Bisexual, or Transgender (M...   262    86
# 36                                  Anti-Heterosexual    23    12
# 37                                      Anti-Bisexual    27     8
# 38                                        Disability:    76    35
# 39                                      Anti-Physical    29    14
# 40                                        Anti-Mental    47    21
# 41                                            Gender:    36    18
# 42                                          Anti-Male    10    10
# 43                                        Anti-Female    26     8
# 44                                   Gender Identity:   130    30
# 45                                   Anti-Transgender   111    27
# 46                         Anti-Gender Non-Conforming    19     3
# 47                           Multiple-Bias Incidents2    94    19
#
# 4  Black or\nAfrican\nAmerican American\nIndian or\nAlaska Native Asian  \
# 6                         1307                                 49    45
# 7                          781                                 37    32
# 8                          452                                 20     6
# 9                           80                                  9    17
# 10                          28                                  2     0
# 11                          20                                  2     6
# 12                           4                                  0     0
# 13                          33                                  0     1
# 14                           6                                  0     1
# 15                         114                                  2     0
# 16                          44                                  2     1
# 17                         118                                  5     5
# 18                          34                                  4     0
# 19                           3                                  0     2
# 20                           2                                  0     0
# 21                          49                                  1     2
# 22                          20                                  0     1
# 23                           1                                  0     0
# 24                           2                                  0     0
# 25                           0                                  0     0
# 26                           3                                  0     0
# 27                           2                                  0     0
# 28                           0                                  0     0
# 29                           0                                  0     0
# 30                           1                                  0     0
# 31                           1                                  0     0
# 32                         326                                  6     6
# 33                         223                                  2     1
# 34                          37                                  0     0
# 35                          53                                  4     3
# 36                           1                                  0     2
# 37                          12                                  0     0
# 38                          16                                  1     1
# 39                           8                                  0     1
# 40                           8                                  1     0
# 41                           9                                  0     0
# 42                           0                                  0     0
# 43                           9                                  0     0
# 44                          57                                  0     1
# 45                          54                                  0     0
# 46                           3                                  0     1
# 47                          24                                  0     0
#
# 4  Native\nHawaiian\nor Other\nPacific\nIslander Group\nof\nmultiple\nraces  \
# 6                                              7                        242
# 7                                              2                        150
# 8                                              0                         27
# 9                                              1                         88
# 10                                             0                          3
# 11                                             0                          5
# 12                                             0                          0
# 13                                             0                          9
# 14                                             0                          3
# 15                                             1                         12
# 16                                             0                          3
# 17                                             2                         32
# 18                                             0                         12
# 19                                             0                          3
# 20                                             0                          0
# 21                                             0                          9
# 22                                             2                          1
# 23                                             0                          4
# 24                                             0                          0
# 25                                             0                          0
# 26                                             0                          0
# 27                                             0                          1
# 28                                             0                          0
# 29                                             0                          1
# 30                                             0                          1
# 31                                             0                          0
# 32                                             3                         49
# 33                                             2                         33
# 34                                             0                          3
# 35                                             1                         12
# 36                                             0                          1
# 37                                             0                          0
# 38                                             0                          1
# 39                                             0                          1
# 40                                             0                          0
# 41                                             0                          1
# 42                                             0                          0
# 43                                             0                          1
# 44                                             0                          9
# 45                                             0                          9
# 46                                             0                          0
# 47                                             0                          3
#
# 4  Unknown\nrace Hispanic\nor\nLatino Not\nHispanic\nor\nLatino  \
# 6            993                  252                       998
# 7            398                  135                       662
# 8             80                   22                       169
# 9            202                   82                       267
# 10            14                    1                         3
# 11             9                    6                        28
# 12             0                    0                         1
# 13            17                    2                        31
# 14             6                    4                        16
# 15            24                   15                       112
# 16            46                    3                        35
# 17           410                   23                       100
# 18           300                    9                        16
# 19            22                    4                         3
# 20             3                    0                         8
# 21            66                    5                        40
# 22             7                    2                        16
# 23             4                    0                         4
# 24             0                    0                         4
# 25             0                    0                         0
# 26             1                    0                         4
# 27             6                    3                         1
# 28             0                    0                         0
# 29             0                    0                         2
# 30             1                    0                         2
# 31             0                    0                         0
# 32           156                   80                       177
# 33           102                   63                       126
# 34            14                    6                        24
# 35            37                   10                        20
# 36             0                    1                         1
# 37             3                    0                         6
# 38             6                    2                        14
# 39             2                    0                         7
# 40             4                    2                         7
# 41             4                    0                         8
# 42             0                    0                         2
# 43             4                    0                         6
# 44            19                   12                        37
# 45            14                   12                        33
# 46             5                    0                         4
# 47            17                    2                        28
#
# 4  Group of\nmultiple\nethnicities Unknown\nethnicity   NaN  NaN  NaN
# 6                               38               2476  1923  NaN  NaN  NaN
# 7                               22               1618  1054  NaN  NaN  NaN
# 8                                9                393   158  NaN  NaN  NaN
# 9                                5                808   583  NaN  NaN  NaN
# 10                               0                 92    58  NaN  NaN  NaN
# 11                               3                 40    24  NaN  NaN  NaN
# 12                               0                  3     1  NaN  NaN  NaN
# 13                               1                 50    64  NaN  NaN  NaN
# 14                               0                 14     8  NaN  NaN  NaN
# 15                               2                150    68  NaN  NaN  NaN
# 16                               2                 68    90  NaN  NaN  NaN
# 17                               9                364   577  NaN  NaN  NaN
# 18                               4                152   328  NaN  NaN  NaN
# 19                               0                 14    24  NaN  NaN  NaN
# 20                               0                  6     4  NaN  NaN  NaN
# 21                               2                121   119  NaN  NaN  NaN
# 22                               2                 18    39  NaN  NaN  NaN
# 23                               0                 21    19  NaN  NaN  NaN
# 24                               0                  0     4  NaN  NaN  NaN
# 25                               0                  0     1  NaN  NaN  NaN
# 26                               0                 15     9  NaN  NaN  NaN
# 27                               0                  5    24  NaN  NaN  NaN
# 28                               0                  0     1  NaN  NaN  NaN
# 29                               0                  5     2  NaN  NaN  NaN
# 30                               1                  4     0  NaN  NaN  NaN
# 31                               0                  3     3  NaN  NaN  NaN
# 32                               7                406   258  NaN  NaN  NaN
# 33                               6                209   145  NaN  NaN  NaN
# 34                               0                 34    36  NaN  NaN  NaN
# 35                               1                140    66  NaN  NaN  NaN
# 36                               0                  9     7  NaN  NaN  NaN
# 37                               0                 14     4  NaN  NaN  NaN
# 38                               0                 39    16  NaN  NaN  NaN
# 39                               0                 14     3  NaN  NaN  NaN
# 40                               0                 25    13  NaN  NaN  NaN
# 41                               0                 17     4  NaN  NaN  NaN
# 42                               0                  8     0  NaN  NaN  NaN
# 43                               0                  9     4  NaN  NaN  NaN
# 44                               0                 32    14  NaN  NaN  NaN
# 45                               0                 30     7  NaN  NaN  NaN
# 46                               0                  2     7  NaN  NaN  NaN
# 47                               0                 28    31  NaN  NaN  NaN

# %%
races.drop(columns=['total', 14, 15, 16])
races.drop([6], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-3704970f62ae> in <module>()
#       1 races.drop(columns=['total', 14, 15, 16])
# ----> 2 races.drop([6], inplace=True)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: 'labels [6] not contained in axis'

# %%
races
# Out:
# 4                                          crime_type total White  \
# 7                            Race/Ethnicity/Ancestry:  4229  1775
# 8                                          Anti-White   876   133
# 9                      Anti-Black or African American  2122  1142
# 10              Anti-American Indian or Alaska Native   161    56
# 11                                         Anti-Asian   131    65
# 12     Anti-Native Hawaiian or Other Pacific Islander     9     4
# 13                         Anti-Multiple Races, Group   178    54
# 14                                          Anti-Arab    56    32
# 15                            Anti-Hispanic or Latino   449   228
# 16                 Anti-Other Race/Ethnicity/Ancestry   247    61
# 17                                          Religion:  1538   389
# 18                                        Anti-Jewish   834   156
# 19                                      Anti-Catholic    63     9
# 20                                    Anti-Protestant    20    11
# 21                              Anti-Islamic (Muslim)   381   135
# 22                                Anti-Other Religion    90    20
# 23                     Anti-Multiple Religions, Group    48    20
# 24                                        Anti-Mormon     8     2
# 25                             Anti-Jehovah's Witness     3     2
# 26      Anti-Eastern Orthodox (Russian, Greek, Other)    28    15
# 27                               Anti-Other Christian    37     4
# 28                                      Anti-Buddhist     1     0
# 29                                         Anti-Hindu    12     9
# 30                                          Anti-Sikh     7     4
# 31                      Anti-Atheism/Agnosticism/etc.     6     2
# 32                                Sexual Orientation:  1218   414
# 33                                    Anti-Gay (Male)   765   257
# 34                                       Anti-Lesbian   141    51
# 35  Anti-Lesbian, Gay, Bisexual, or Transgender (M...   262    86
# 36                                  Anti-Heterosexual    23    12
# 37                                      Anti-Bisexual    27     8
# 38                                        Disability:    76    35
# 39                                      Anti-Physical    29    14
# 40                                        Anti-Mental    47    21
# 41                                            Gender:    36    18
# 42                                          Anti-Male    10    10
# 43                                        Anti-Female    26     8
# 44                                   Gender Identity:   130    30
# 45                                   Anti-Transgender   111    27
# 46                         Anti-Gender Non-Conforming    19     3
# 47                           Multiple-Bias Incidents2    94    19
#
# 4  Black or\nAfrican\nAmerican American\nIndian or\nAlaska Native Asian  \
# 7                          781                                 37    32
# 8                          452                                 20     6
# 9                           80                                  9    17
# 10                          28                                  2     0
# 11                          20                                  2     6
# 12                           4                                  0     0
# 13                          33                                  0     1
# 14                           6                                  0     1
# 15                         114                                  2     0
# 16                          44                                  2     1
# 17                         118                                  5     5
# 18                          34                                  4     0
# 19                           3                                  0     2
# 20                           2                                  0     0
# 21                          49                                  1     2
# 22                          20                                  0     1
# 23                           1                                  0     0
# 24                           2                                  0     0
# 25                           0                                  0     0
# 26                           3                                  0     0
# 27                           2                                  0     0
# 28                           0                                  0     0
# 29                           0                                  0     0
# 30                           1                                  0     0
# 31                           1                                  0     0
# 32                         326                                  6     6
# 33                         223                                  2     1
# 34                          37                                  0     0
# 35                          53                                  4     3
# 36                           1                                  0     2
# 37                          12                                  0     0
# 38                          16                                  1     1
# 39                           8                                  0     1
# 40                           8                                  1     0
# 41                           9                                  0     0
# 42                           0                                  0     0
# 43                           9                                  0     0
# 44                          57                                  0     1
# 45                          54                                  0     0
# 46                           3                                  0     1
# 47                          24                                  0     0
#
# 4  Native\nHawaiian\nor Other\nPacific\nIslander Group\nof\nmultiple\nraces  \
# 7                                              2                        150
# 8                                              0                         27
# 9                                              1                         88
# 10                                             0                          3
# 11                                             0                          5
# 12                                             0                          0
# 13                                             0                          9
# 14                                             0                          3
# 15                                             1                         12
# 16                                             0                          3
# 17                                             2                         32
# 18                                             0                         12
# 19                                             0                          3
# 20                                             0                          0
# 21                                             0                          9
# 22                                             2                          1
# 23                                             0                          4
# 24                                             0                          0
# 25                                             0                          0
# 26                                             0                          0
# 27                                             0                          1
# 28                                             0                          0
# 29                                             0                          1
# 30                                             0                          1
# 31                                             0                          0
# 32                                             3                         49
# 33                                             2                         33
# 34                                             0                          3
# 35                                             1                         12
# 36                                             0                          1
# 37                                             0                          0
# 38                                             0                          1
# 39                                             0                          1
# 40                                             0                          0
# 41                                             0                          1
# 42                                             0                          0
# 43                                             0                          1
# 44                                             0                          9
# 45                                             0                          9
# 46                                             0                          0
# 47                                             0                          3
#
# 4  Unknown\nrace Hispanic\nor\nLatino Not\nHispanic\nor\nLatino  \
# 7            398                  135                       662
# 8             80                   22                       169
# 9            202                   82                       267
# 10            14                    1                         3
# 11             9                    6                        28
# 12             0                    0                         1
# 13            17                    2                        31
# 14             6                    4                        16
# 15            24                   15                       112
# 16            46                    3                        35
# 17           410                   23                       100
# 18           300                    9                        16
# 19            22                    4                         3
# 20             3                    0                         8
# 21            66                    5                        40
# 22             7                    2                        16
# 23             4                    0                         4
# 24             0                    0                         4
# 25             0                    0                         0
# 26             1                    0                         4
# 27             6                    3                         1
# 28             0                    0                         0
# 29             0                    0                         2
# 30             1                    0                         2
# 31             0                    0                         0
# 32           156                   80                       177
# 33           102                   63                       126
# 34            14                    6                        24
# 35            37                   10                        20
# 36             0                    1                         1
# 37             3                    0                         6
# 38             6                    2                        14
# 39             2                    0                         7
# 40             4                    2                         7
# 41             4                    0                         8
# 42             0                    0                         2
# 43             4                    0                         6
# 44            19                   12                        37
# 45            14                   12                        33
# 46             5                    0                         4
# 47            17                    2                        28
#
# 4  Group of\nmultiple\nethnicities Unknown\nethnicity   NaN  NaN  NaN
# 7                               22               1618  1054  NaN  NaN  NaN
# 8                                9                393   158  NaN  NaN  NaN
# 9                                5                808   583  NaN  NaN  NaN
# 10                               0                 92    58  NaN  NaN  NaN
# 11                               3                 40    24  NaN  NaN  NaN
# 12                               0                  3     1  NaN  NaN  NaN
# 13                               1                 50    64  NaN  NaN  NaN
# 14                               0                 14     8  NaN  NaN  NaN
# 15                               2                150    68  NaN  NaN  NaN
# 16                               2                 68    90  NaN  NaN  NaN
# 17                               9                364   577  NaN  NaN  NaN
# 18                               4                152   328  NaN  NaN  NaN
# 19                               0                 14    24  NaN  NaN  NaN
# 20                               0                  6     4  NaN  NaN  NaN
# 21                               2                121   119  NaN  NaN  NaN
# 22                               2                 18    39  NaN  NaN  NaN
# 23                               0                 21    19  NaN  NaN  NaN
# 24                               0                  0     4  NaN  NaN  NaN
# 25                               0                  0     1  NaN  NaN  NaN
# 26                               0                 15     9  NaN  NaN  NaN
# 27                               0                  5    24  NaN  NaN  NaN
# 28                               0                  0     1  NaN  NaN  NaN
# 29                               0                  5     2  NaN  NaN  NaN
# 30                               1                  4     0  NaN  NaN  NaN
# 31                               0                  3     3  NaN  NaN  NaN
# 32                               7                406   258  NaN  NaN  NaN
# 33                               6                209   145  NaN  NaN  NaN
# 34                               0                 34    36  NaN  NaN  NaN
# 35                               1                140    66  NaN  NaN  NaN
# 36                               0                  9     7  NaN  NaN  NaN
# 37                               0                 14     4  NaN  NaN  NaN
# 38                               0                 39    16  NaN  NaN  NaN
# 39                               0                 14     3  NaN  NaN  NaN
# 40                               0                 25    13  NaN  NaN  NaN
# 41                               0                 17     4  NaN  NaN  NaN
# 42                               0                  8     0  NaN  NaN  NaN
# 43                               0                  9     4  NaN  NaN  NaN
# 44                               0                 32    14  NaN  NaN  NaN
# 45                               0                 30     7  NaN  NaN  NaN
# 46                               0                  2     7  NaN  NaN  NaN
# 47                               0                 28    31  NaN  NaN  NaN

# %%
races_transposed = races.T
#races_transposed.drop([14,15,16])
races_transposed
# Out:
#                                                                      7   \
# 4
# crime_type                                     Race/Ethnicity/Ancestry:
# total                                                              4229
# White                                                              1775
# Black or\nAfrican\nAmerican                                         781
# American\nIndian or\nAlaska Native                                   37
# Asian                                                                32
# Native\nHawaiian\nor Other\nPacific\nIslander                         2
# Group\nof\nmultiple\nraces                                          150
# Unknown\nrace                                                       398
# Hispanic\nor\nLatino                                                135
# Not\nHispanic\nor\nLatino                                           662
# Group of\nmultiple\nethnicities                                      22
# Unknown\nethnicity                                                 1618
# NaN                                                                1054
# NaN                                                                 NaN
# NaN                                                                 NaN
#                                                                     NaN
#
#                                                        8   \
# 4
# crime_type                                     Anti-White
# total                                                 876
# White                                                 133
# Black or\nAfrican\nAmerican                           452
# American\nIndian or\nAlaska Native                     20
# Asian                                                   6
# Native\nHawaiian\nor Other\nPacific\nIslander           0
# Group\nof\nmultiple\nraces                             27
# Unknown\nrace                                          80
# Hispanic\nor\nLatino                                   22
# Not\nHispanic\nor\nLatino                             169
# Group of\nmultiple\nethnicities                         9
# Unknown\nethnicity                                    393
# NaN                                                   158
# NaN                                                   NaN
# NaN                                                   NaN
#                                                       NaN
#
#                                                                            9   \
# 4
# crime_type                                     Anti-Black or African American
# total                                                                    2122
# White                                                                    1142
# Black or\nAfrican\nAmerican                                                80
# American\nIndian or\nAlaska Native                                          9
# Asian                                                                      17
# Native\nHawaiian\nor Other\nPacific\nIslander                               1
# Group\nof\nmultiple\nraces                                                 88
# Unknown\nrace                                                             202
# Hispanic\nor\nLatino                                                       82
# Not\nHispanic\nor\nLatino                                                 267
# Group of\nmultiple\nethnicities                                             5
# Unknown\nethnicity                                                        808
# NaN                                                                       583
# NaN                                                                       NaN
# NaN                                                                       NaN
#                                                                           NaN
#
#                                                                                   10  \
# 4
# crime_type                                     Anti-American Indian or Alaska Native
# total                                                                            161
# White                                                                             56
# Black or\nAfrican\nAmerican                                                       28
# American\nIndian or\nAlaska Native                                                 2
# Asian                                                                              0
# Native\nHawaiian\nor Other\nPacific\nIslander                                      0
# Group\nof\nmultiple\nraces                                                         3
# Unknown\nrace                                                                     14
# Hispanic\nor\nLatino                                                               1
# Not\nHispanic\nor\nLatino                                                          3
# Group of\nmultiple\nethnicities                                                    0
# Unknown\nethnicity                                                                92
# NaN                                                                               58
# NaN                                                                              NaN
# NaN                                                                              NaN
#                                                                                  NaN
#
#                                                        11  \
# 4
# crime_type                                     Anti-Asian
# total                                                 131
# White                                                  65
# Black or\nAfrican\nAmerican                            20
# American\nIndian or\nAlaska Native                      2
# Asian                                                   6
# Native\nHawaiian\nor Other\nPacific\nIslander           0
# Group\nof\nmultiple\nraces                              5
# Unknown\nrace                                           9
# Hispanic\nor\nLatino                                    6
# Not\nHispanic\nor\nLatino                              28
# Group of\nmultiple\nethnicities                         3
# Unknown\nethnicity                                     40
# NaN                                                    24
# NaN                                                   NaN
# NaN                                                   NaN
#                                                       NaN
#
#                                                                                            12  \
# 4
# crime_type                                     Anti-Native Hawaiian or Other Pacific Islander
# total                                                                                       9
# White                                                                                       4
# Black or\nAfrican\nAmerican                                                                 4
# American\nIndian or\nAlaska Native                                                          0
# Asian                                                                                       0
# Native\nHawaiian\nor Other\nPacific\nIslander                                               0
# Group\nof\nmultiple\nraces                                                                  0
# Unknown\nrace                                                                               0
# Hispanic\nor\nLatino                                                                        0
# Not\nHispanic\nor\nLatino                                                                   1
# Group of\nmultiple\nethnicities                                                             0
# Unknown\nethnicity                                                                          3
# NaN                                                                                         1
# NaN                                                                                       NaN
# NaN                                                                                       NaN
#                                                                                           NaN
#
#                                                                        13  \
# 4
# crime_type                                     Anti-Multiple Races, Group
# total                                                                 178
# White                                                                  54
# Black or\nAfrican\nAmerican                                            33
# American\nIndian or\nAlaska Native                                      0
# Asian                                                                   1
# Native\nHawaiian\nor Other\nPacific\nIslander                           0
# Group\nof\nmultiple\nraces                                              9
# Unknown\nrace                                                          17
# Hispanic\nor\nLatino                                                    2
# Not\nHispanic\nor\nLatino                                              31
# Group of\nmultiple\nethnicities                                         1
# Unknown\nethnicity                                                     50
# NaN                                                                    64
# NaN                                                                   NaN
# NaN                                                                   NaN
#                                                                       NaN
#
#                                                       14  \
# 4
# crime_type                                     Anti-Arab
# total                                                 56
# White                                                 32
# Black or\nAfrican\nAmerican                            6
# American\nIndian or\nAlaska Native                     0
# Asian                                                  1
# Native\nHawaiian\nor Other\nPacific\nIslander          0
# Group\nof\nmultiple\nraces                             3
# Unknown\nrace                                          6
# Hispanic\nor\nLatino                                   4
# Not\nHispanic\nor\nLatino                             16
# Group of\nmultiple\nethnicities                        0
# Unknown\nethnicity                                    14
# NaN                                                    8
# NaN                                                  NaN
# NaN                                                  NaN
#                                                      NaN
#
#                                                                     15  \
# 4
# crime_type                                     Anti-Hispanic or Latino
# total                                                              449
# White                                                              228
# Black or\nAfrican\nAmerican                                        114
# American\nIndian or\nAlaska Native                                   2
# Asian                                                                0
# Native\nHawaiian\nor Other\nPacific\nIslander                        1
# Group\nof\nmultiple\nraces                                          12
# Unknown\nrace                                                       24
# Hispanic\nor\nLatino                                                15
# Not\nHispanic\nor\nLatino                                          112
# Group of\nmultiple\nethnicities                                      2
# Unknown\nethnicity                                                 150
# NaN                                                                 68
# NaN                                                                NaN
# NaN                                                                NaN
#                                                                    NaN
#
#                                                                                16  \
# 4
# crime_type                                     Anti-Other Race/Ethnicity/Ancestry
# total                                                                         247
# White                                                                          61
# Black or\nAfrican\nAmerican                                                    44
# American\nIndian or\nAlaska Native                                              2
# Asian                                                                           1
# Native\nHawaiian\nor Other\nPacific\nIslander                                   0
# Group\nof\nmultiple\nraces                                                      3
# Unknown\nrace                                                                  46
# Hispanic\nor\nLatino                                                            3
# Not\nHispanic\nor\nLatino                                                      35
# Group of\nmultiple\nethnicities                                                 2
# Unknown\nethnicity                                                             68
# NaN                                                                            90
# NaN                                                                           NaN
# NaN                                                                           NaN
#                                                                               NaN
#
#                                                          ...             \
# 4                                                        ...
# crime_type                                               ...
# total                                                    ...
# White                                                    ...
# Black or\nAfrican\nAmerican                              ...
# American\nIndian or\nAlaska Native                       ...
# Asian                                                    ...
# Native\nHawaiian\nor Other\nPacific\nIslander            ...
# Group\nof\nmultiple\nraces                               ...
# Unknown\nrace                                            ...
# Hispanic\nor\nLatino                                     ...
# Not\nHispanic\nor\nLatino                                ...
# Group of\nmultiple\nethnicities                          ...
# Unknown\nethnicity                                       ...
# NaN                                                      ...
# NaN                                                      ...
# NaN                                                      ...
#                                                          ...
#
#                                                         38             39  \
# 4
# crime_type                                     Disability:  Anti-Physical
# total                                                   76             29
# White                                                   35             14
# Black or\nAfrican\nAmerican                             16              8
# American\nIndian or\nAlaska Native                       1              0
# Asian                                                    1              1
# Native\nHawaiian\nor Other\nPacific\nIslander            0              0
# Group\nof\nmultiple\nraces                               1              1
# Unknown\nrace                                            6              2
# Hispanic\nor\nLatino                                     2              0
# Not\nHispanic\nor\nLatino                               14              7
# Group of\nmultiple\nethnicities                          0              0
# Unknown\nethnicity                                      39             14
# NaN                                                     16              3
# NaN                                                    NaN            NaN
# NaN                                                    NaN            NaN
#                                                        NaN            NaN
#
#                                                         40       41  \
# 4
# crime_type                                     Anti-Mental  Gender:
# total                                                   47       36
# White                                                   21       18
# Black or\nAfrican\nAmerican                              8        9
# American\nIndian or\nAlaska Native                       1        0
# Asian                                                    0        0
# Native\nHawaiian\nor Other\nPacific\nIslander            0        0
# Group\nof\nmultiple\nraces                               0        1
# Unknown\nrace                                            4        4
# Hispanic\nor\nLatino                                     2        0
# Not\nHispanic\nor\nLatino                                7        8
# Group of\nmultiple\nethnicities                          0        0
# Unknown\nethnicity                                      25       17
# NaN                                                     13        4
# NaN                                                    NaN      NaN
# NaN                                                    NaN      NaN
#                                                        NaN      NaN
#
#                                                       42           43  \
# 4
# crime_type                                     Anti-Male  Anti-Female
# total                                                 10           26
# White                                                 10            8
# Black or\nAfrican\nAmerican                            0            9
# American\nIndian or\nAlaska Native                     0            0
# Asian                                                  0            0
# Native\nHawaiian\nor Other\nPacific\nIslander          0            0
# Group\nof\nmultiple\nraces                             0            1
# Unknown\nrace                                          0            4
# Hispanic\nor\nLatino                                   0            0
# Not\nHispanic\nor\nLatino                              2            6
# Group of\nmultiple\nethnicities                        0            0
# Unknown\nethnicity                                     8            9
# NaN                                                    0            4
# NaN                                                  NaN          NaN
# NaN                                                  NaN          NaN
#                                                      NaN          NaN
#
#                                                              44  \
# 4
# crime_type                                     Gender Identity:
# total                                                       130
# White                                                        30
# Black or\nAfrican\nAmerican                                  57
# American\nIndian or\nAlaska Native                            0
# Asian                                                         1
# Native\nHawaiian\nor Other\nPacific\nIslander                 0
# Group\nof\nmultiple\nraces                                    9
# Unknown\nrace                                                19
# Hispanic\nor\nLatino                                         12
# Not\nHispanic\nor\nLatino                                    37
# Group of\nmultiple\nethnicities                               0
# Unknown\nethnicity                                           32
# NaN                                                          14
# NaN                                                         NaN
# NaN                                                         NaN
#                                                             NaN
#
#                                                              45  \
# 4
# crime_type                                     Anti-Transgender
# total                                                       111
# White                                                        27
# Black or\nAfrican\nAmerican                                  54
# American\nIndian or\nAlaska Native                            0
# Asian                                                         0
# Native\nHawaiian\nor Other\nPacific\nIslander                 0
# Group\nof\nmultiple\nraces                                    9
# Unknown\nrace                                                14
# Hispanic\nor\nLatino                                         12
# Not\nHispanic\nor\nLatino                                    33
# Group of\nmultiple\nethnicities                               0
# Unknown\nethnicity                                           30
# NaN                                                           7
# NaN                                                         NaN
# NaN                                                         NaN
#                                                             NaN
#
#                                                                        46  \
# 4
# crime_type                                     Anti-Gender Non-Conforming
# total                                                                  19
# White                                                                   3
# Black or\nAfrican\nAmerican                                             3
# American\nIndian or\nAlaska Native                                      0
# Asian                                                                   1
# Native\nHawaiian\nor Other\nPacific\nIslander                           0
# Group\nof\nmultiple\nraces                                              0
# Unknown\nrace                                                           5
# Hispanic\nor\nLatino                                                    0
# Not\nHispanic\nor\nLatino                                               4
# Group of\nmultiple\nethnicities                                         0
# Unknown\nethnicity                                                      2
# NaN                                                                     7
# NaN                                                                   NaN
# NaN                                                                   NaN
#                                                                       NaN
#
#                                                                      47
# 4
# crime_type                                     Multiple-Bias Incidents2
# total                                                                94
# White                                                                19
# Black or\nAfrican\nAmerican                                          24
# American\nIndian or\nAlaska Native                                    0
# Asian                                                                 0
# Native\nHawaiian\nor Other\nPacific\nIslander                         0
# Group\nof\nmultiple\nraces                                            3
# Unknown\nrace                                                        17
# Hispanic\nor\nLatino                                                  2
# Not\nHispanic\nor\nLatino                                            28
# Group of\nmultiple\nethnicities                                       0
# Unknown\nethnicity                                                   28
# NaN                                                                  31
# NaN                                                                 NaN
# NaN                                                                 NaN
#                                                                     NaN
#
# [17 rows x 41 columns]

# %%
races_transposed.plot(x='crime_type', kind='barh', stacked=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'crime_type'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-5b9374eeef44> in <module>()
# ----> 1 races_transposed.plot(x='crime_type', kind='barh', stacked=True)
#       2 plt.show()
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1764                 if is_integer(x) and not data.columns.holds_integer():
#    1765                     x = data_cols[x]
# -> 1766                 elif not isinstance(data[x], ABCSeries):
#    1767                     raise ValueError("x must be a label or position")
#    1768                 data = data.set_index(x)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'crime_type'

# %%
test_df = races.T

# %%
test_df.reset_index(inplace=True)

# %%
test_df.columns = test_df.iloc[0]

# %%
test_df.drop([0], inplace=True)

# %%
test_df.rename(columns={test_df.columns[0]: "offender_race" }, inplace=True)

# %%
test_df.drop([1, 8, 10, 12, 13, 14, 15, 16], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-a3914e504d81> in <module>()
# ----> 1 test_df.drop([1, 8, 10, 12, 13, 14, 15, 16], inplace=True)
#       2 test_df
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: 'labels [ 1  8 10 12 13 14 15 16] not contained in axis'

# %%
test_df
# Out:
# 0                                   offender_race Race/Ethnicity/Ancestry:  \
# 2                                           White                     1775
# 3                     Black or\nAfrican\nAmerican                      781
# 4              American\nIndian or\nAlaska Native                       37
# 5                                           Asian                       32
# 6   Native\nHawaiian\nor Other\nPacific\nIslander                        2
# 7                      Group\nof\nmultiple\nraces                      150
# 9                            Hispanic\nor\nLatino                      135
# 11                Group of\nmultiple\nethnicities                       22
#
# 0  Anti-White Anti-Black or African American  \
# 2         133                           1142
# 3         452                             80
# 4          20                              9
# 5           6                             17
# 6           0                              1
# 7          27                             88
# 9          22                             82
# 11          9                              5
#
# 0  Anti-American Indian or Alaska Native Anti-Asian  \
# 2                                     56         65
# 3                                     28         20
# 4                                      2          2
# 5                                      0          6
# 6                                      0          0
# 7                                      3          5
# 9                                      1          6
# 11                                     0          3
#
# 0  Anti-Native Hawaiian or Other Pacific Islander Anti-Multiple Races, Group  \
# 2                                               4                         54
# 3                                               4                         33
# 4                                               0                          0
# 5                                               0                          1
# 6                                               0                          0
# 7                                               0                          9
# 9                                               0                          2
# 11                                              0                          1
#
# 0  Anti-Arab Anti-Hispanic or Latino           ...            Disability:  \
# 2         32                     228           ...                     35
# 3          6                     114           ...                     16
# 4          0                       2           ...                      1
# 5          1                       0           ...                      1
# 6          0                       1           ...                      0
# 7          3                      12           ...                      1
# 9          4                      15           ...                      2
# 11         0                       2           ...                      0
#
# 0  Anti-Physical Anti-Mental Gender: Anti-Male Anti-Female Gender Identity:  \
# 2             14          21      18        10           8               30
# 3              8           8       9         0           9               57
# 4              0           1       0         0           0                0
# 5              1           0       0         0           0                1
# 6              0           0       0         0           0                0
# 7              1           0       1         0           1                9
# 9              0           2       0         0           0               12
# 11             0           0       0         0           0                0
#
# 0  Anti-Transgender Anti-Gender Non-Conforming Multiple-Bias Incidents2
# 2                27                          3                       19
# 3                54                          3                       24
# 4                 0                          0                        0
# 5                 0                          1                        0
# 6                 0                          0                        0
# 7                 9                          0                        3
# 9                12                          0                        2
# 11                0                          0                        0
#
# [8 rows x 42 columns]

# %%
test_df.rename(columns={test_df.columns[1]: "race_crimes", test_df.columns[2]: "anti_white", test_df.columns[3]: "anti_black", test_df.columns[4]: "anti_native", test_df.columns[5]: "anti_asian", test_df.columns[6]: "anti_hawaiian", test_df.columns[7]: "anti_everyone", test_df.columns[8]: "anti_arab", test_df.columns[9]: "anti_hispanic", test_df.columns[10]: "anti_other",}, inplace=True)

# %%
# totals df contains the total number of race, religion, disability, etc crimes, sorted by race of offender
totals_df = test_df[['offender_race', 'race_crimes', 'Religion:', 'Sexual Orientation:', 'Disability:', 'Gender:', 'Gender Identity:']]
totals_df
# Out:
# 0                                   offender_race race_crimes Religion:  \
# 2                                           White        1775       389
# 3                     Black or\nAfrican\nAmerican         781       118
# 4              American\nIndian or\nAlaska Native          37         5
# 5                                           Asian          32         5
# 6   Native\nHawaiian\nor Other\nPacific\nIslander           2         2
# 7                      Group\nof\nmultiple\nraces         150        32
# 9                            Hispanic\nor\nLatino         135        23
# 11                Group of\nmultiple\nethnicities          22         9
#
# 0  Sexual Orientation: Disability: Gender: Gender Identity:
# 2                  414          35      18               30
# 3                  326          16       9               57
# 4                    6           1       0                0
# 5                    6           1       0                1
# 6                    3           0       0                0
# 7                   49           1       1                9
# 9                   80           2       0               12
# 11                   7           0       0                0

# %%
ax = totals_df.sort_values(by='race_crimes', ascending=False).plot(x='offender_race', kind='bar', stacked=True, figsize=(12,6))
ax.grid(False, axis='x')
ax.set_title("2016 U.S. hate crimes by offender race", pad=20)
ax.set_xlabel("Race of offender")
ax.set_ylabel("")
ax.spines.bottom=True

plt.tight_layout()
plt.savefig("2016-total-hate-crimes.pdf", facecolor=plt.gcf().get_facecolor())

# %%
totals2_df = test_df[['offender_race', 'Disability:', 'Gender:', 'Gender Identity:']]
totals2_df.drop([6,11], inplace=True)
# Out:
# /Users/Veronica/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
ax = totals2_df.sort_values(by='Gender Identity:', ascending=False).plot(x='offender_race', kind='bar', stacked=True, figsize=(12,6), color=['#8bccc9', '#f9d669', '#EBA239'])
ax.grid(False, axis='x')
ax.set_title("2016 U.S. Hate Crimes", pad=20)
ax.set_xlabel("Race of offender")
ax.set_ylabel("")
ax.spines.bottom=True

plt.tight_layout()
plt.savefig("2016-select-hate-crimes.pdf", facecolor=plt.gcf().get_facecolor())

# %%
totals2_df

# %%
gender_identity = test_df[['offender_race', 'Anti-Transgender',  'Anti-Gender Non-Conforming', 'Anti-Female', 'Anti-Male']]
gender_identity

# %%
gender_identity.drop([4, 6, 11], inplace=True)

# %%
ax = gender_identity.sort_values(by='Anti-Transgender', ascending=False).plot(x='offender_race', kind='bar', stacked=True, figsize=(12,6))
ax.grid(False, axis='x')
ax.set_title("2016 U.S. Gender and Gender Identity Crimes", pad=20)
ax.set_xlabel("Race of offender")
ax.set_ylabel("")
ax.spines.bottom=True

plt.tight_layout()
plt.savefig("gender-crimes.pdf", facecolor=plt.gcf().get_facecolor())

# %%
test_df

# %%
#test_df.offender_race
list(test_df.columns.values)

# %%
test_df.drop([1, 13, 14, 15, 16], inplace=True)

# %%
ax = test_df.plot(x='offender_race', kind='bar', stacked=True, figsize=(12,6))
#ax.legend_=None

plt.show()

# %%
location.head()

# %%
location.drop([0,1,2,3,52,53], inplace=True)
location.head()

# %%
location.columns = location.iloc[0]
location.reset_index(inplace=True)
location.drop([0], inplace=True)
location.head()

# %%
#location.drop(columns=['index'], inplace=True)
location.columns.values[0] = 'location'
location.columns.values[1] = 'total'
location

# %%
location.columns.values[8] = 'test'
location.columns.values[12] = 'test2'
location

# %%
location_corrected['location']

# %%
location_corrected=location[['location', 'Race/\nEthnicity/\nAncestry', 'Religion', 'Sexual\norientation', 'Disability', 'Gender', 'Gender\nIdentity']]
location_corrected.drop([1, 21, 32, 46, 47], inplace=True)
location_corrected

# %%
location_corrected.index

# %%
#loc = location_corrected.reset_index().replace({'location': {'School/college2':'School—college/university'}}).groupby('location', sort=False).sum()
location_corrected.loc[39] += location_corrected.loc[40]

# %%
location_corrected.drop([40], inplace=True)
location_corrected

# %%
ax = location_corrected.sort_values(by='Race/\nEthnicity/\nAncestry', ascending=True).tail(10).plot(x='location', kind='barh', figsize=(12,6), stacked=True)
ax.grid(False, axis='y')
ax.set_title("Most common locations of hate crimes", pad=20)
ax.set_xlabel("Number of crimes")
ax.set_ylabel("")

plt.tight_layout()
plt.savefig("crime-location.pdf", facecolor=plt.gcf().get_facecolor())

# %%
# get just the locations for disability, gender, and gender identity-motivated crimes
location_sample=location[['location', 'Disability', 'Gender', 'Gender\nIdentity']]

# %%
location_sample.drop([1,2,4,6,7,9,10,11,13,14,16,17,19,21,23,28,30,31,32,37,44,45], inplace=True)

# %%
location_sample.sort_values(by='Gender\nIdentity', ascending=True).plot(x='location', kind='barh', figsize=(10,8))
plt.show()

# %%
race_location = location_sample[['Race/\nEthnicity/\nAncestry']]
race_location

# %%
location_sample.drop([1,2,6,7,14,17,19,21,23,32,44], inplace=True)

# %%
location_sample.sort_values(by='Sexual\norientation', ascending=True).plot(x='location', kind='barh', figsize=(10,8), stacked=True)
plt.show()

# %%
# waffle chart with race of offender
