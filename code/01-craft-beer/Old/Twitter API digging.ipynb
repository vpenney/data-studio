# %%
import requests

# %%
client_key = 'lXR6VPD9YofNpSTLVS0X7Jacz'
client_secret = 'T7BG8k9eOP2Hbc4kX8Hf5WMZ3QvAmp4J9r8POtfkt8RLPDpUFd'

import base64

key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
base_url = 'https://api.twitter.com/'
auth_url = '{}oauth2/token'.format(base_url)

auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

auth_data = {
    'grant_type': 'client_credentials'
}

auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)

# %%
# Check status code okay
auth_resp.status_code
# Out:
# 200

# %%
access_token = auth_resp.json()['access_token']

# %%
search_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}

search_params = {
    'q': 'mezcal',
    'count': 100
}

search_url = 'https://api.twitter.com/1.1/tweets/search/fullarchive/dev.json'
#'{}1.1/search/tweets.json'.format(base_url)

# need to use app url
# https://api.twitter.com/1.1/tweets/search/30day/dev.json

search_resp = requests.get(search_url, headers=search_headers, params=search_params)
search_resp
# Out:
# <Response [422]>

# %%
tweet_data = search_resp.json()
tweet_info = tweet_data['statuses'][1]
#tweet_info['user']['location']

# %%
for tweet in tweet_data['statuses']:
    print(tweet['created_at'], tweet['coordinates'])
    tweet_info=tweet['user']
    print(tweet_info['location'] + '\n')
# Out:
# Thu Jul 12 16:15:15 +0000 2018 None
# ÷versos&multiversos
#
# Thu Jul 12 16:15:04 +0000 2018 None
#
#
# Thu Jul 12 16:14:58 +0000 2018 None
# My latest single "Small Talk" is an @Xtina tribute:
#
# Thu Jul 12 16:14:20 +0000 2018 None
# Oaxaca
#
# Thu Jul 12 16:13:52 +0000 2018 None
# En el Planeta Tierra
#
# Thu Jul 12 16:13:30 +0000 2018 None
# Vallarta-Nayarit, México
#
# Thu Jul 12 16:13:02 +0000 2018 None
# Oaxaca
#
# Thu Jul 12 16:12:59 +0000 2018 {'type': 'Point', 'coordinates': [-103.37044443, 20.67319644]}
# Guadalajara, Jalisco
#
# Thu Jul 12 16:12:35 +0000 2018 None
# Vivo en su imaginación
#
# Thu Jul 12 16:12:19 +0000 2018 None
#
#
# Thu Jul 12 16:12:18 +0000 2018 None
# México, Oaxaca
#
# Thu Jul 12 16:10:40 +0000 2018 None
#
#
# Thu Jul 12 16:09:02 +0000 2018 None
# Acapulco de Juárez, Guerrero
#
# Thu Jul 12 16:08:03 +0000 2018 None
# ¡Debajo de tus sábanas!
#
# Thu Jul 12 16:06:18 +0000 2018 None
#
#
# Thu Jul 12 16:05:01 +0000 2018 None
#
#
# ...
